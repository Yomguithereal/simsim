# %% [markdown]
# # SimSim

# %%
import json
import math
import networkx as nx
import community
from collections import defaultdict, Counter
from ipysigma import Sigma
from fog.metrics import sparse_dot_product
from tqdm import tqdm_notebook

# %% [markdown]
# ## Loading the recipes

# %%
with open('./recipes.json', 'r') as f:
    RECIPES = json.load(f)

for i, recipe in enumerate(RECIPES[0:2]):
    title = 'Recipe n°%i' % (i + 1)
    print(title)
    print('-' * len(title))
    
    for ingredient in recipe['ingredients']:
        print(ingredient)
        
    print()
print('...')
# Out:
# Recipe n°1
# ----------
# romaine lettuce
# black olives
# grape tomatoes
# garlic
# pepper
# purple onion
# seasoning
# garbanzo beans
# feta cheese crumbles
#
# Recipe n°2
# ----------
# plain flour
# ground pepper
# salt
# tomatoes
# ground black pepper
# thyme
# eggs
# green tomatoes
# yellow corn meal
# milk
# vegetable oil
#
# ...

# %% [markdown]
# ## Computing the similarity matrix

# %%
VECTORS = defaultdict(Counter)
OCCURRENCES = Counter()
for recipe in RECIPES:
    ingredients = recipe['ingredients']
    
    for i in range(len(ingredients)):
        A = ingredients[i]
        OCCURRENCES[A] += 1
        for j in range(i + 1, len(ingredients)):
            B = ingredients[j]
            
            VECTORS[A][B] += 1
            VECTORS[B][A] += 1
            
print(VECTORS['milk'].most_common(5))
print(OCCURRENCES['milk'])
print(len(VECTORS))
# Out:
# [('salt', 1354), ('butter', 835), ('all-purpose flour', 791), ('eggs', 734), ('sugar', 598)]
# 2263
# 6714

# %%
NORMS = {}
for ingredient, vector in VECTORS.items():
    NORMS[ingredient] = math.sqrt(sum(map(lambda x: x * x, vector.values())))
    
NORMS['milk']
# Out:
# 2372.3218584332103

# %%
MATRIX = defaultdict(dict)

for kA, A in tqdm_notebook(VECTORS.items()):
    nA = NORMS[kA]
    for kB in A:
        B = VECTORS[kB]
        nB = NORMS[kB]
        s = sparse_dot_product(A, B) / (nA * nB)

        MATRIX[kA][kB] = s
        MATRIX[kB][kA] = s
# Out:
# HBox(children=(IntProgress(value=0, max=6714), HTML(value='')))

# %%
# Test
MATRIX['milk']
# Out:
# {'romaine lettuce': 0.5134933486688922,
#  'black olives': 0.533048360905154,
#  'grape tomatoes': 0.5611005584053758,
#  'garlic': 0.683404109215867,
#  'pepper': 0.7637984053377127,
#  'purple onion': 0.5922018304105658,
#  'seasoning': 0.7089089720897498,
#  'garbanzo beans': 0.5659175741891418,
#  'feta cheese crumbles': 0.4926559481988714,
#  'plain flour': 0.8179936460180105,
#  'ground pepper': 0.6819179548190523,
#  'salt': 0.6285361460756537,
#  'tomatoes': 0.6565334785735949,
#  'ground black pepper': 0.720209028576445,
#  'thyme': 0.6817052055189198,
#  'eggs': 0.8716422724926906,
#  'green tomatoes': 0.7749376761979361,
#  'yellow corn meal': 0.8513965277198132,
#  'vegetable oil': 0.7594391139084048,
#  'black pepper': 0.7400020800190426,
#  'shallots': 0.685053065968898,
#  'cornflour': 0.48359074820275616,
#  'cayenne pepper': 0.7056420388327814,
#  'onions': 0.6955679894301807,
#  'garlic paste': 0.4861823467246021,
#  'butter': 0.8663688396858132,
#  'lemon juice': 0.7940761667055567,
#  'water': 0.7867581626842027,
#  'chili powder': 0.6066871875438424,
#  'passata': 0.4997643606684028,
#  'oil': 0.7106483967196506,
#  'ground cumin': 0.6070026706941157,
#  'boneless chicken skinless thigh': 0.606673110480858,
#  'garam masala': 0.5465874139620871,
#  'double cream': 0.6342515198907596,
#  'natural yogurt': 0.3880232885600982,
#  'bay leaf': 0.6665889387239993,
#  'sugar': 0.8219812233995972,
#  'fresh ginger root': 0.5259548023416065,
#  'ground cinnamon': 0.8495061584833166,
#  'vanilla extract': 0.848234168121783,
#  'ground ginger': 0.6944792086229129,
#  'powdered sugar': 0.8320052849389681,
#  'baking powder': 0.890316259027488,
#  'melted butter': 0.9034870025242819,
#  'matcha green tea powder': 0.5318113933254355,
#  'white sugar': 0.8623346922388615,
#  'all-purpose flour': 0.8756437682076308,
#  'chopped walnuts': 0.8719968230713991,
#  'vanilla': 0.8361626574668801,
#  'large egg yolks': 0.7605499373769368,
#  'corn starch': 0.6529110330032502,
#  'self rising flour': 0.7588430387896148,
#  'confectioners sugar': 0.8256230777799569,
#  'softened butter': 0.8005254474673983,
#  'food colouring': 0.7141754043907501,
#  'buttermilk': 0.8679710938168955,
#  'sirloin tip roast': 0.24170648319387966,
#  'coarse salt': 0.5007184634506555,
#  'steak': 0.6697096787371978,
#  'granulated sugar': 0.8282914638539814,
#  'vegetable shortening': 0.845855279715797,
#  'grated parmesan cheese': 0.710572384423704,
#  'chopped celery': 0.6515367389610839,
#  'mustard powder': 0.6967593239379836,
#  'cod': 0.6544545649427269,
#  'minced onion': 0.7634496582337084,
#  'potatoes': 0.7162910052202751,
#  'red bell pepper': 0.6328112852323997,
#  'chopped green bell pepper': 0.610850599027718,
#  'old bay seasoning': 0.721505220540212,
#  'dry bread crumbs': 0.7907505540808049,
#  'egg yolks': 0.8593644367764076,
#  'cinnamon sticks': 0.5881539317892878,
#  'flour': 0.8778285149284526,
#  'lard': 0.7867492847984215,
#  'frozen whipped topping': 0.4392004323079834,
#  'chocolate instant pudding': 0.31155193258462704,
#  'instant butterscotch pudding mix': 0.17413959557407,
#  'cream cheese': 0.8510347730375422,
#  'graham cracker crumbs': 0.5968520935588314,
#  'taco sauce': 0.3025412787322381,
#  'guacamole': 0.3801092150489086,
#  'salsa verde': 0.47865034418958413,
#  'shredded cabbage': 0.623260250692689,
#  'dried oregano': 0.6336152605857345,
#  'kosher salt': 0.5182685081228807,
#  'sweet onion': 0.6916258356241257,
#  'condiments': 0.3799888048414809,
#  'avocado': 0.5115748360000998,
#  'pork shoulder roast': 0.5617901882985125,
#  'tortillas': 0.4968560994475945,
#  'cumin': 0.5792746751200268,
#  'shortening': 0.8888480555097431,
#  'honey': 0.7422786241885491,
#  'unsalted butter': 0.8350920067695556,
#  'jam': 0.7995031932442848,
#  'baking soda': 0.8644079975102164,
#  'dried currants': 0.7825362587757133,
#  'sesame seeds': 0.5150416640275159,
#  'granulated garlic': 0.5562801573198488,
#  'chicken breasts': 0.6699382240964196,
#  'toasted sesame oil': 0.396845924395534,
#  'chicken broth': 0.7164651824944119,
#  'soy sauce': 0.5275341267120416,
#  'vinegar': 0.6891722888955557,
#  'large eggs': 0.8658103299828112,
#  'sauce': 0.7403373674403831,
#  'cajun seasoning': 0.6789582755576344,
#  'shrimp': 0.6975560414208921,
#  'fry mix': 0.3388187154742378,
#  'yellow mustard': 0.612671151725851,
#  'chocolate sauce': 0.5931927367413481,
#  'ricotta cheese': 0.684740542346914,
#  'slivered almonds': 0.8262082887027042,
#  'orange zest': 0.8343138204118952,
#  'orange juice': 0.7399107280305527,
#  'coriander seeds': 0.4847737854782746,
#  'boiling water': 0.8247752763896299,
#  'cauliflower': 0.6052403490841023,
#  'tamarind pulp': 0.375190648468511,
#  'coconut cream': 0.5622501637736664,
#  'chickpea flour': 0.5428974280885833,
#  'mustard seeds': 0.5237736860528293,
#  'ground cloves': 0.7326855639686147,
#  'eggplant': 0.6145092170653502,
#  'plain breadcrumbs': 0.6188726657708163,
#  'diced tomatoes': 0.6087685817939874,
#  'tomato paste': 0.6653783923915622,
#  'olive oil': 0.6921968369453453,
#  'ground allspice': 0.7165795330222638,
#  'ground lamb': 0.6288019854128959,
#  'dry red wine': 0.6179629466809592,
#  'grated nutmeg': 0.8033951420834122,
#  'boneless skinless chicken breasts': 0.6501713160642102,
#  'condensed cream of mushroom soup': 0.41970259998917125,
#  'fettuccine pasta': 0.5105680531552736,
#  'broccoli': 0.5422700230777443,
#  'McCormick Parsley Flakes': 0.3685559487744985,
#  'bread': 0.8032057745400307,
#  'lump crab meat': 0.6641577784321618,
#  'worcestershire sauce': 0.7327510631482913,
#  'mayonaise': 0.7267843189979253,
#  'egg whites': 0.8567327435204143,
#  'margarine': 0.8550838438949675,
#  'greek yogurt': 0.6328240287706155,
#  "Campbell's Condensed Tomato Soup": 0.0897304851119087,
#  'chunky salsa': 0.42124151231766666,
#  'flour tortillas': 0.5091219428531166,
#  'shredded cheddar cheese': 0.5572693571620694,
#  'ground beef': 0.6654514665759019,
#  'beef bouillon granules': 0.5281839040438504,
#  'deli ham': 0.6831712418492123,
#  'fresh parsley': 0.7164668392183671,
#  'tenderloin roast': 0.4959276481889411,
#  'beef consomme': 0.5737289957400618,
#  'fresh mushrooms': 0.7175276713503836,
#  'Madeira': 0.5800489226905939,
#  'frozen pastry puff sheets': 0.8049602236892964,
#  'raisin bread': 0.35289531569120214,
#  'ground nutmeg': 0.8677119920208225,
#  'sweetened coconut flakes': 0.8062749025036119,
#  'light brown sugar': 0.7594191005859215,
#  'bananas': 0.8289304818881736,
#  'carrots': 0.6667262778379605,
#  'baking mix': 0.5890676557777946,
#  'frozen peas': 0.6395011065270351,
#  'condensed cream of chicken soup': 0.3832836564793732,
#  'poultry seasoning': 0.7379421049719743,
#  'boneless skinless chicken breast halves': 0.6960995232414179,
#  'garlic powder': 0.7131457364538247,
#  'Kraft Grated Parmesan Cheese': 0.17609842973312642,
#  'pasta': 0.6161799191620928,
#  'peas': 0.6774565115715715,
#  'Oscar Mayer Bacon': 0.07799307626878373,
#  'Philadelphia Cream Cheese': 0.3420412917241497,
#  'cocoa powder': 0.8085289144219389,
#  'peaches': 0.8191969422520191,
#  'cinnamon': 0.7998234128874941,
#  'parmesan cheese': 0.7090736414301472,
#  'superfine sugar': 0.7301558407562685,
#  'chives': 0.7738995123473608,
#  'sour cream': 0.6509106228544751,
#  'country ham': 0.7653903384665778,
#  'panko breadcrumbs': 0.7693857577300582,
#  'cooking spray': 0.7231680319809921,
#  'italian seasoning': 0.6428601534966588,
#  'garlic salt': 0.6832853426941838,
#  'chicken fingers': 0.5648235317435047,
#  'celery ribs': 0.5810560753845703,
#  'sliced almonds': 0.8004233006847586,
#  'water chestnuts': 0.45679029622596906,
#  'andouille sausage': 0.5232094539164988,
#  'green bell pepper': 0.6358248044841044,
#  'cooked chicken': 0.596476558279356,
#  'cream of mushroom soup': 0.4812336597717698,
#  'bread crumb fresh': 0.6928800601125699,
#  'black-eyed peas': 0.6043022854741272,
#  'long grain and wild rice mix': 0.40068721047632017,
#  'low sodium chicken broth': 0.6226439983739448,
#  'cornmeal': 0.8913831146538512,
#  'cold water': 0.8469616680207506,
#  'sweetened condensed milk': 0.7222441217412447,
#  'Jell-O Gelatin Dessert': 0.10485508073693081,
#  'crushed tomatoes': 0.6220203885345058,
#  'parmigiano reggiano cheese': 0.6568142657488014,
#  'freshly ground pepper': 0.7005427697024864,
#  'flat leaf parsley': 0.606052457184182,
#  'yellow onion': 0.6288117551315842,
#  'juice': 0.6435153241227237,
#  'fresh basil': 0.5843868943370005,
#  'ground pork': 0.6346080141371688,
#  'garlic cloves': 0.6713810632930552,
#  'romana': 0.1481384446214292,
#  'prosciutto': 0.620101839048292,
#  'fresh oregano': 0.5488851455143291,
#  'gnocchi': 0.6000155934734259,
#  'bread crumbs': 0.8224503863801044,
#  'green onions': 0.6580004221843052,
#  'bacon': 0.7850336436527084,
#  'elbow macaroni': 0.7510378086895747,
#  'sharp cheddar cheese': 0.8167457943657237,
#  'gravy': 0.7229887900604738,
#  'seasoned flour': 0.380812145410445,
#  'peanut oil': 0.5880732125158403,
#  'onion powder': 0.580865655307525,
#  'round steaks': 0.6119319826477598,
#  'chopped almonds': 0.833706890966451,
#  'Grand Marnier': 0.5529779860011544,
#  'pastry cream': 0.636859306501306,
#  'cognac': 0.7492600786139085,
#  'grated lemon zest': 0.7518046782877071,
#  'white pepper': 0.6549307446452137,
#  'fettucine': 0.6278130461411106,
#  'frozen broccoli': 0.537919703441907,
#  'grating cheese': 0.6699709977113549,
#  'tapioca flour': 0.7448676673153944,
#  'raisins': 0.8640520601053814,
#  'toasted walnuts': 0.7665700334012583,
#  'orange': 0.7086835996470976,
#  'dark rum': 0.754558875972773,
#  'dried fig': 0.7322993918874299,
#  'lemon': 0.760256370259436,
#  'greens': 0.6108226852469056,
#  'warm water': 0.8260096517105473,
#  'dough': 0.7947787360258559,
#  'cream': 0.8108869392915851,
#  'cake': 0.6621130871272333,
#  'icing': 0.5911768803639983,
#  'yeast': 0.8231497688296275,
#  'walnuts': 0.7542958835139901,
#  'rose water': 0.49186453634354077,
#  'white vinegar': 0.7334917768651362,
#  'ketchup': 0.6643071586983185,
#  'ground turmeric': 0.5552810824788617,
#  'chicken bouillon': 0.6808753552196855,
#  'coconut milk': 0.5803432064427073,
#  'ground paprika': 0.6379182104640779,
#  'curry powder': 0.6493703162120847,
#  'ground almonds': 0.7266675468381771,
#  'raspberries': 0.4963840507685123,
#  'glace cherries': 0.3454802550958294,
#  'fresh raspberries': 0.5313778663209604,
#  'raspberry jam': 0.4756098189056568,
#  'silver dragees': 0.17685436634894508,
#  'biscuits': 0.760174402716132,
#  'caster sugar': 0.6794632173149011,
#  'frozen raspberries': 0.21613838424568624,
#  'sponge cake': 0.312902754128209,
#  'sweet sherry': 0.303568656637489,
#  'vanilla pods': 0.24146932392686227,
#  'whipping cream': 0.803808549833091,
#  'cottage cheese': 0.7139955800958697,
#  'farmer cheese': 0.8037392095081964,
#  'shrimp shells': 0.5558511634981507,
#  'white wine': 0.6942436933512667,
#  'grits': 0.7304338333209046,
#  'heavy cream': 0.8788874801145459,
#  'fresh herbs': 0.6348462613014509,
#  'parmigiano-reggiano cheese': 0.5689411532233246,
#  'bay leaves': 0.6435352108304716,
#  'sourdough bread': 0.5294606455799129,
#  'ground cayenne pepper': 0.6496774604175207,
#  'swiss cheese': 0.7858509186420072,
#  'frozen whole kernel corn': 0.6074879742259943,
#  'masa harina': 0.644591760816916,
#  'rolled oats': 0.7729757293540883,
#  'golden syrup': 0.6570220964255038,
#  'granola': 0.07676006720857984,
#  'mango': 0.5754686208431252,
#  'coconut': 0.6157835191582076,
#  'frozen mixed berries': 0.27438848060248927,
#  'ice': 0.37163040491202615,
#  'hot sauce': 0.7028000127722627,
#  'cream of tartar': 0.778466747017796,
#  'molasses': 0.7428002389986387,
#  'vegetable oil cooking spray': 0.7673826979587375,
#  'fresh cilantro': 0.5887436460450414,
#  'chicken': 0.7086854580402089,
#  'lean ground beef': 0.6411134017836124,
#  'dry mustard': 0.7841316089396625,
#  'sweet paprika': 0.5843145307944455,
#  'white onion': 0.588077485183251,
#  'dry sherry': 0.6138482332458098,
#  'white sandwich bread': 0.5986613483129862,
#  'currant jelly': 0.4436043296591682,
#  'mace': 0.5250095933569694,
#  'seasoned bread crumbs': 0.6790366801981855,
#  'minced garlic': 0.6896328590816351,
#  'grated romano cheese': 0.6138776891720611,
#  'quinoa': 0.4564503795886485,
#  'duck drippings': 0.2779955520125814,
#  'dried thyme': 0.6820388102051048,
#  'fat': 0.7038762413409394,
#  'dry white wine': 0.6382897190893467,
#  'duck': 0.541621965297161,
#  'toast': 0.6183528989057613,
#  'low salt chicken broth': 0.5244469374065166,
#  'dulce de leche': 0.4481744577766321,
#  'pure vanilla extract': 0.7042831831366811,
#  'bittersweet chocolate': 0.6625368876626117,
#  'whipped cream': 0.7237701052605643,
#  'mexican chocolate': 0.4893627526910429,
#  'sweet potatoes': 0.817551040088164,
#  'cornbread stuffing mix': 0.4735907398116046,
#  'large garlic cloves': 0.6047147736770646,
#  'half & half': 0.8983540091956072,
#  'evaporated milk': 0.906287742589441,
#  'fresh lemon juice': 0.6876518681356772,
#  'roasted red peppers': 0.5806622283711326,
#  'shredded mozzarella cheese': 0.5985526527214506,
#  'capers': 0.5677870566660338,
#  'chopped tomatoes': 0.5938591880377548,
#  'chopped parsley': 0.7208220766521196,
#  'pitted black olives': 0.5082350994595263,
#  'sliced green onions': 0.6528037109167107,
#  'saltine crumbs': 0.419216811915104,
#  'ground red pepper': 0.6782367363689317,
#  'cooked shrimp': 0.665011624797899,
#  'coffee': 0.6893818219361557,
#  'white bread': 0.763782862922537,
#  'red pepper flakes': 0.5976475483793554,
#  'ground white pepper': 0.6897981356471982,
#  'sherry vinegar': 0.5155531059888552,
#  'coarse-grain salt': 0.1397862323852717,
#  'toasted almonds': 0.7074431419908358,
#  'saffron threads': 0.5466958180045458,
#  'hungarian sweet paprika': 0.4544834574603374,
#  'roasted hazelnuts': 0.6728112442086205,
#  'leeks': 0.6680348525686534,
#  'extra-virgin olive oil': 0.6110556755644584,
#  'country bread': 0.414919967690265,
#  'quickcooking grits': 0.7183329967486731,
#  'barbecue sauce': 0.6052163304210797,
#  'kahlua': 0.36101466216678185,
#  'instant espresso powder': 0.5602849843513596,
#  'OREO® Cookies': 0.3991454159701581,
#  'dark chocolate': 0.7345435454093903,
#  'unsweetened cocoa powder': 0.7904990752160003,
#  'salsa': 0.4536083166932764,
#  'hot pepper sauce': 0.7173343349057573,
#  'chorizo sausage': 0.5934509740170444,
#  'shredded Monterey Jack cheese': 0.5239580958111427,
#  'corn tortillas': 0.5326042312421205,
#  'oregano': 0.6266418270059481,
#  'whole milk ricotta cheese': 0.6660545519445306,
#  'dried basil': 0.6092883108180308,
#  'grated parmesan romano': 0.44094010827887575,
#  'lasagna noodles': 0.5790446442972534,
#  'cream cheese, soften': 0.7700679164768798,
#  'green peas': 0.6705173137369378,
#  'salmon fillets': 0.6375669659738371,
#  'cooking oil': 0.678861622132546,
#  'chopped fresh chives': 0.7406445508898961,
#  'cayenne': 0.712452334557212,
#  'boiling potatoes': 0.6573313898321113,
#  'creole seasoning': 0.5966276745255529,
#  'long pasta': 0.20541231395376583,
#  'cabbage': 0.6554533979947781,
#  'corn': 0.5785848022589377,
#  'monterey jack': 0.5607153017087769,
#  'red pepper': 0.5962182772332242,
#  'green pepper': 0.6276662860736295,
#  'noodles': 0.5454047102037154,
#  'refrigerated piecrusts': 0.8076369694370129,
#  'sweet potatoes or yams': 0.4240684088450428,
#  'firmly packed brown sugar': 0.7651555894660325,
#  "I Can't Believe It's Not Butter!® Spread": 0.47134581738355263,
#  'whole wheat flour': 0.8558385878393704,
#  'medium eggs': 0.7731328762185458,
#  'drippings': 0.5870845687257462,
#  'unflavored gelatin': 0.48963885735122437,
#  'vanilla beans': 0.6023249265972074,
#  'Frangelico': 0.48414060714083884,
#  'vegetable oil spray': 0.6959123855437798,
#  'sirloin steak': 0.5280447670180831,
#  'bacon drippings': 0.8122203980345447,
#  'ham': 0.7795511917988435,
#  'dijon mustard': 0.6738808889424427,
#  'plain yogurt': 0.6610177708494711,
#  'radishes': 0.5571285131688253,
#  'fresh dill': 0.6570339623742683,
#  'cucumber': 0.5858044221082256,
#  'corn husks': 0.6597751923344831,
#  'cotija': 0.5298929785148186,
#  'lime wedges': 0.5202383371676377,
#  'chopped cilantro fresh': 0.5688396673372609,
#  'white cornmeal': 0.7418100916340182,
#  'diced onions': 0.6924236294042118,
#  'cheddar cheese': 0.7082388453990371,
#  'green chilies': 0.5613727409256765,
#  'paneer': 0.4926372944017726,
#  'chopped cilantro': 0.6048172542793283,
#  'amchur': 0.4898031697015497,
#  'coriander powder': 0.455859221392772,
#  'tumeric': 0.5738911069745563,
#  'vegetables': 0.661294195122679,
#  'ginger': 0.5527290875881189,
#  'cumin seed': 0.5456609364807716,
#  'asafetida': 0.4366110953264489,
#  'liqueur': 0.5293962591589314,
#  'golden raisins': 0.7929300698372168,
#  'ranch dressing': 0.5250211972168303,
#  'coke': 0.23818811328340214,
#  'boneless chuck roast': 0.4919355304239642,
#  'chili sauce': 0.4954978068525139,
#  'red curry paste': 0.35245094670021576,
#  'cilantro leaves': 0.5852170408143824,
#  'lamb': 0.6123213693167885,
#  'pork sausages': 0.7387378689955543,
#  'jalapeno chilies': 0.6210537526545047,
#  'taco seasoning': 0.3711091670591912,
#  'jack cheese': 0.5523537608867998,
#  'macaroni': 0.6703348427815246,
#  'shredded sharp cheddar cheese': 0.7533261533628632,
#  'pork': 0.658014545221603,
#  'ground mustard': 0.6697504012316533,
#  'almonds': 0.8172553318907376,
#  'dried parsley': 0.6743182550428295,
#  'self-rising cornmeal': 0.6261385954526588,
#  'catfish fillets': 0.6912115801174674,
#  'seasoning salt': 0.6971593207766785,
#  'baking spray': 0.57198290113858,
#  'bread flour': 0.7129053395750932,
#  'lavender': 0.32461944769987405,
#  'instant yeast': 0.7677435830739275,
#  'bourbon whiskey': 0.8048655800373108,
#  'cooked ham': 0.7218023990968937,
#  'powdered milk': 0.7229712014191462,
#  'ground cardamom': 0.6495271298747981,
#  'maida flour': 0.5343476814847892,
#  'rose essence': 0.23960083270277244,
#  'ghee': 0.5521896726439237,
#  'soft-wheat flour': 0.6127941368700419,
#  'almond extract': 0.7896432115411876,
#  'mashed potatoes': 0.8331309509580858,
#  'spring onions': 0.5271832372325177,
#  'nutmeg': 0.821095388824581,
#  'grated lemon peel': 0.6978172039478083,
#  'white flour': 0.7512522820203367,
#  'lemon zest': 0.7929784085660517,
#  'strawberry jam': 0.5804782033508824,
#  'strong white bread flour': 0.5295693376505847,
#  'clotted cream': 0.5574182969880657,
#  'vanilla essence': 0.6126402408695168,
#  'glutinous rice flour': 0.5419299232872506,
#  'frozen corn': 0.534936577754203,
#  'orange blossom extract': 0.5670999551445804,
#  'brandy': 0.8396337111005429,
#  'chocolate': 0.7511827359951028,
#  'silken tofu': 0.3869300584564891,
#  'cold milk': 0.7989214509513323,
#  'white rice': 0.6555903583861543,
#  'green chile': 0.5903868824735945,
#  'chile powder': 0.5644548512714318,
#  'corn kernels': 0.696475087401412,
#  'extra sharp cheddar cheese': 0.7549450333923049,
#  'salt and ground black pepper': 0.5029203045121525,
#  'crust': 0.6713275138618071,
#  'clams': 0.47861834290660615,
#  'fontina cheese': 0.6733014562547225,
#  'green bell pepper, slice': 0.5113420556024075,
#  'portobello caps': 0.3433129348960816,
#  'red bell pepper, sliced': 0.38641959746285165,
#  'poppy seeds': 0.7097651644955439,
#  'vanilla wafers': 0.6265684533717515,
#  'brown sugar': 0.7311275294471352,
#  'sausages': 0.6840820569442708,
#  'mustard': 0.7332031896990295,
#  'Guinness Beer': 0.7213677655215014,
#  'apples': 0.8551701110657419,
#  'cake flour': 0.7779972368874789,
#  'fine granulated sugar': 0.41756362492954213,
#  'coconut extract': 0.6724019295550292,
#  'flaked coconut': 0.7071943045084157,
#  'light corn syrup': 0.7349811419661895,
#  'shell pasta': 0.514370965882367,
#  'paprika': 0.6979862001341239,
#  'dry yeast': 0.6541263052454281,
#  'kirsch': 0.5860336004654074,
#  'dried tart cherries': 0.7204987042442992,
#  'mint leaves': 0.5539888458173057,
#  'cardamom': 0.5115768654251823,
#  'peppercorns': 0.5431301440760641,
#  'yoghurt': 0.5813851527298249,
#  'star anise': 0.4516359592323999,
#  'basmati rice': 0.5658770574303139,
#  'clove': 0.552197139465266,
#  'Biryani Masala': 0.2934155494309182,
#  'saffron': 0.6096461883692801,
#  'whole wheat pastry flour': 0.7923585353685737,
#  'maple syrup': 0.8191074657705208,
#  'cream of chicken soup': 0.4404445428374229,
#  'part-skim mozzarella cheese': 0.5052440231141793,
#  'tortilla chips': 0.44204022832667983,
#  'shredded parmesan cheese': 0.6193301458934912,
#  'peeled shrimp': 0.5675234101624357,
#  'white chocolate': 0.628943156469514,
#  'french bread': 0.7217217435817201,
#  'crawfish': 0.6685061534084045,
#  'chopped onion': 0.6390405567019737,
#  'black tea': 0.46377387846942963,
#  'fresh ginger': 0.5522239089779578,
#  'cream sweeten whip': 0.6602913529051039,
#  'tea bags': 0.40719545078072805,
#  'pecan halves': 0.7969083519322289,
#  'mini marshmallows': 0.6952110725641574,
#  'fruit': 0.686919610815697,
#  'cherries': 0.7256054989143399,
#  'glaze': 0.7772414408767991,
#  'active dry yeast': 0.8054277806128564,
#  'fruit filling': 0.4901884974260315,
#  'whole milk': 0.8707053279264105,
#  'canola oil': 0.6967973773484751,
#  'pistachio nuts': 0.667888863459721,
#  'Tabasco Pepper Sauce': 0.6947691561466691,
#  'crepes': 0.6068319194388015,
#  'dried tarragon leaves': 0.6688355819857797,
#  'finely chopped onion': 0.6907440989978477,
#  'pink grapefruit juice': 0.39641685064846105,
#  'pink grapefruit': 0.47371016220672135,
#  'unbaked pie crusts': 0.675763414806731,
#  'beef': 0.6189767331326914,
#  'idaho potatoes': 0.6937700115829704,
#  'cantal': 0.4742189581067222,
#  'haricots verts': 0.5350354424293724,
#  'sea salt': 0.5129706379386976,
#  'rib eye steaks': 0.45621191965142127,
#  'red wine': 0.6798686298606158,
#  'baby carrots': 0.6047021372996685,
#  'chervil': 0.465723127397392,
#  'port': 0.6190726038842158,
#  'corn mix muffin': 0.4577259160825363,
#  'shredded extra sharp cheddar cheese': 0.6706708107104622,
#  'black beans': 0.4740900894099135,
#  'diced green chilies': 0.5055329627215702,
#  'cornbread mix': 0.5114478071055917,
#  'rum': 0.795930033590745,
#  'candy bar': 0.6238750659077773,
#  'heavy whipping cream': 0.8648632934005576,
#  'cherry tomatoes': 0.5531269156278463,
#  'sharp white cheddar cheese': 0.6262931894923053,
#  'Sriracha': 0.43772921847002805,
#  'thick-cut bacon': 0.6698533052913171,
#  'sliced turkey': 0.36965299367746157,
#  'nuts': 0.6292933327975225,
#  'cream style corn': 0.8227651101313204,
#  'enchilada sauce': 0.43521814273103104,
#  'chopped pecans': 0.8494398379600488,
#  'fresh mozzarella': 0.5823950484283165,
#  'fresh curry leaves': 0.43388121286251585,
#  'ground coriander': 0.5263834320925234,
#  'frozen chopped spinach': 0.7075942465937404,
#  'chile pepper': 0.6540340303199033,
#  'baked beans': 0.5023441398399292,
#  'dark brown sugar': 0.7361929975716647,
#  'croissants': 0.4103391101773509,
#  'caster': 0.3208851349245222,
#  'spicy brown mustard': 0.6397129538943986,
#  'port wine': 0.7891662094736213,
#  'fresh sage': 0.693946616603619,
#  'chicken bouillon granules': 0.7436294978857385,
#  'fresh thyme': 0.6650005952664845,
#  'Ritz Crackers': 0.5420922867074881,
#  'celery': 0.6349877782977951,
#  'pimentos': 0.6721269275916243,
#  'rotisserie chicken': 0.48727031132489956,
#  'doritos': 0.13078883417284073,
#  'shredded cheese': 0.4864178961960313,
#  'soy milk': 0.616464631289417,
#  'gluten': 0.5739504098894253,
#  'japanese rice': 0.4873768357920104,
#  'parsley': 0.7177252166470576,
#  'minced beef': 0.6191367260852985,
#  'sweet corn': 0.5951733961071238,
#  'semisweet chocolate': 0.6710917405562057,
#  'condensed milk': 0.5885734857096556,
#  'chips': 0.6082881706109087,
#  'granny smith apples': 0.8065751382600359,
#  'vidalia onion': 0.6842747849946629,
#  'queso fresco': 0.4901552515099616,
#  'all purpose unbleached flour': 0.7475427631089988,
#  'cracked black pepper': 0.6859910101958281,
#  'Emmenthal': 0.596527893627154,
#  'haddock fillets': 0.6066229294665864,
#  'crème fraîche': 0.8086338468331682,
#  'rolls': 0.6404706902996015,
#  'green cabbage': 0.6020855160029187,
#  'balsamic vinegar': 0.5812421518814348,
#  'kale': 0.5529151571664371,
#  'fine sea salt': 0.4863171340922853,
#  'russet potatoes': 0.7246238759313681,
#  'fusilli': 0.49157682690414456,
#  'yellow bell pepper': 0.513827205422481,
#  'blue cheese': 0.6457002089389898,
#  'cheese soup': 0.12524891200492827,
#  'turkey burger': 0.007587503329707556,
#  'cheese': 0.7070024950961193,
#  'serrano': 0.5323315071627206,
#  'cranberries': 0.653230142324431,
#  'low-fat ricotta cheese': 0.3912052065118306,
#  'tomato purée': 0.6580490329168337,
#  'freshly grated parmesan': 0.5715396809006817,
#  'pumpkin': 0.7486028640902886,
#  'baby spinach': 0.6636027247970834,
#  'fennel bulb': 0.49915286545964643,
#  'fresh chives': 0.7450166847031378,
#  'frozen peas and carrots': 0.5276231174593333,
#  'strawberries': 0.6127664153092455,
#  'lean minced beef': 0.4145787644634718,
#  'beef stock': 0.6948947105158316,
#  'dried mixed herbs': 0.5487280982077208,
#  'penne pasta': 0.5439161056159804,
#  'ground turkey': 0.5951775923536546,
#  'light cream cheese': 0.649800834373706,
#  'mexican style 4 cheese blend': 0.2154287358251741,
#  'chipotles in adobo': 0.530925289435067,
#  'lemon peel': 0.6395136551308448,
#  'hard-boiled egg': 0.6616861464362788,
#  'dried salted codfish': 0.6169860947769199,
#  'fresh cod': 0.305370280534605,
#  'zucchini': 0.6098436284435214,
#  'vermicelli': 0.6015289197261817,
#  'citron': 0.5984787838194919,
#  'currant': 0.7904716744388754,
#  'macaroni and cheese dinner': 0.15439781552092618,
#  'lemon rind': 0.6961950628967141,
#  'brewed espresso': 0.31605225251372887,
#  'beef drippings': 0.681238368524607,
#  'cocoa': 0.797031063281329,
#  'ground meat': 0.6163637059140905,
#  'seeds': 0.6253299312053776,
#  'chili flakes': 0.6001246602375122,
#  'chiles': 0.5868701311093418,
#  'curry': 0.512018473518719,
#  'serrano chilies': 0.49637709547771086,
#  'pico de gallo': 0.4144326208311345,
#  'rigatoni': 0.488338852761738,
#  'nonstick spray': 0.6396489307289338,
#  'asadero': 0.38225884382530184,
#  'sausage links': 0.624533331636856,
#  'savory': 0.5940019311793291,
#  'reduced sodium chicken broth': 0.5985881417586879,
#  'collard greens': 0.6514112656019831,
#  'medium shrimp uncook': 0.3332693778073008,
#  'blackening seasoning': 0.3669950965638731,
#  'lemon pepper': 0.59584567696426,
#  'ham steak': 0.6097296243563345,
#  'marmite': 0.49155971585574487,
#  'graham cracker crusts': 0.39668865190747127,
#  'lime zest': 0.5457506323340315,
#  'whipped topping': 0.5244057791974168,
#  'key lime juice': 0.5152970063624328,
#  'shortcrust pastry': 0.36905498491808403,
#  'medium curry powder': 0.2556899642512919,
#  'breakfast sausages': 0.7542904150314033,
#  'pistachios': 0.7290390867700223,
#  'asparagus spears': 0.6972224171149144,
#  'toasted cashews': 0.31083174823307663,
#  'beaten eggs': 0.8143674582557857,
#  'luke warm water': 0.5225209572059276,
#  'orange peel': 0.6081684642474396,
#  'grated orange peel': 0.7267118417123576,
#  'chocolate shavings': 0.5186065669626938,
#  'candied fruit': 0.7562311070382681,
#  'yellow cake mix': 0.46450721196843164,
#  'vanilla instant pudding': 0.4066152623788156,
#  'Nilla Wafers': 0.4343154654591002,
#  'grated coconut': 0.5817015590008757,
#  'bread mix': 0.40450241493910155,
#  'Mexican cheese blend': 0.43813884840814776,
#  'red enchilada sauce': 0.36738625429774463,
#  'cashew nuts': 0.5715992280489262,
#  'french fried onions': 0.41855967290914703,
#  'chicken pieces': 0.6584693302732196,
#  'red chili powder': 0.5120600396665138,
#  'curds': 0.5215795712289344,
#  'candy sprinkles': 0.7450528218681948,
#  'button mushrooms': 0.665899693681769,
#  'crabmeat': 0.7124095913820055,
#  'yolk': 0.7008171405973894,
#  'pie shell': 0.7474233459192754,
#  'curry leaves': 0.479326341592458,
#  'sweetener': 0.42039283516133275,
#  'millet': 0.3528610576276775,
#  'frozen peaches': 0.7610762978010288,
#  'egg noodles, cooked and drained': 0.5308072637291423,
#  'anise extract': 0.7199141411384532,
#  'udon': 0.3874805965271641,
#  'peanuts': 0.5215555802312049,
#  'crushed red pepper flakes': 0.5924201561348859,
#  'dark sesame oil': 0.36744921009197284,
#  'chopped fresh mint': 0.5482443136907718,
#  'chunky peanut butter': 0.3599461488963141,
#  'rice vinegar': 0.46119644274260796,
#  'beansprouts': 0.4457554745059626,
#  'bacon slices': 0.7388728529418809,
#  'cheddar cheese soup': 0.2204877349864907,
#  'smoked turkey': 0.3405036736112229,
#  'sliced ham': 0.45083845046247506,
#  'penne': 0.5341098783391252,
#  'marinade': 0.5163144184308391,
#  'jamaican jerk season': 0.3965111945367705,
#  'lime juice': 0.5747343181835607,
#  'pineapple juice': 0.5303730901942166,
#  'white corn syrup': 0.4601295301159721,
#  'toasted pecans': 0.7765228326777202,
#  'greek style plain yogurt': 0.6199525532089308,
#  'crumbled goat cheese': 0.3792409425640887,
#  'roast red peppers, drain': 0.4957830464380231,
#  'linguine': 0.5829515403145883,
#  'oven-ready lasagna noodles': 0.555704836073987,
#  'cream cheese with chives and onion': 0.06894674913901809,
#  'boneless chicken breast': 0.6717611497604867,
#  'ground thyme': 0.664304341084674,
#  'gluten free all purpose flour': 0.5050641665055701,
#  'apple cider': 0.762882661261418,
#  'dried fruit': 0.5187542606792968,
#  'chocolate cake mix': 0.32424048449550374,
#  'part-skim ricotta cheese': 0.5888762026657961,
#  'green beans': 0.6200418236948637,
#  'large egg whites': 0.7770393697137208,
#  'cherry preserves': 0.5822888637089649,
#  'gruyere cheese': 0.7623501081475769,
#  'chopped ham': 0.669545126771614,
#  'American cheese': 0.5572787660616624,
#  'pickled jalapenos': 0.4451113532573959,
#  'ice water': 0.867829197747069,
#  'dill': 0.7060945419519775,
#  'mushrooms': 0.7240605396290868,
#  'long-grain rice': 0.6421061514717521,
#  'smoked salmon': 0.6545048046621135,
#  'cheese tortellini': 0.5293216022644658,
#  'fresh asparagus': 0.7016665966818564,
#  'coffee liqueur': 0.4900853531743138,
#  'flavored syrup': 0.10405919577835684,
#  'crushed ice': 0.3002936574854387,
#  'trout fillet': 0.5353903127554331,
#  'parsley sprigs': 0.645790063039482,
#  'couscous': 0.5066688661811694,
#  'corn flour': 0.6959253350971409,
#  'white cheddar cheese': 0.7358103932835934,
#  'rapid rise yeast': 0.7484274827881492,
#  'ragu cheesi classic alfredo sauc': 0.2324648149003456,
#  'Italian bread': 0.5866616156507034,
#  'peach slices': 0.6621089600686254,
#  'cod fillets': 0.6651004864542095,
#  'panko': 0.698734133047327,
#  'pepperoni slices': 0.42381972264867,
#  'tomato sauce': 0.6695340425748676,
#  'top loin': 0.38544516914914384,
#  'dried peach': 0.3835106614612453,
#  'mozzarella cheese': 0.6446885054682286,
#  'poblano peppers': 0.5591403506055344,
#  'biscuit mix': 0.5032491058587256,
#  'tart apples': 0.7268719434979852,
#  'bread slices': 0.6750076621735528,
#  'min': 0.5249689951303426,
#  'liquid': 0.6890855801444785,
#  'orange flavored brandy': 0.2337285561431832,
#  'french toast': 0.26603585918764733,
#  'roasted cashews': 0.5766822362407126,
#  'spices': 0.6440720493358519,
#  'lamb shoulder': 0.5684576117091158,
#  'green cardamom pods': 0.4577595991105005,
#  'canned tomatoes': 0.5996316575884908,
#  'rice': 0.6585544099845789,
#  'low-fat plain yogurt': 0.5997710590087066,
#  'serrano chile': 0.5077687672549231,
#  'pasta sauce': 0.5160324692370689,
#  'spaghetti': 0.6171950065408959,
#  'crumbles': 0.3486044396265049,
#  'scallions': 0.5809253877211541,
#  'cream sherry': 0.4981896119367801,
#  'preserves': 0.44422054532604693,
#  'provolone cheese': 0.5720069755937879,
#  'golden brown sugar': 0.6837983819841958,
#  'pie crust': 0.7904696396045369,
#  'spinach': 0.689229393596016,
#  'jeera': 0.43267091844507816,
#  'asafoetida': 0.4114805769430828,
#  'coriander': 0.5665408368689372,
#  'minced ginger': 0.5005714906872546,
#  'kasuri methi': 0.42546536533101176,
#  'rutabaga': 0.4985819831381757,
#  'rotel tomatoes': 0.4496072606178882,
#  'pepper sauce': 0.5865400305870058,
#  'fresh coriander': 0.5163994170598837,
#  'clear honey': 0.23286081533551073,
#  'chickpeas': 0.5421904372899867,
#  'dried cranberries': 0.8229485837627205,
#  'shelled pistachios': 0.5152330779277,
#  'squash': 0.5684434704791415,
#  'harissa paste': 0.2975429643970774,
#  'blanched almonds': 0.6908827321396169,
#  'fresh spinach': 0.6779087322687652,
#  'phyllo pastry': 0.6401415090292168,
#  'crushed red pepper': 0.5782599782782841,
#  'grated jack cheese': 0.5159384343991641,
#  'extra fine granulated sugar': 0.4464272745105545,
#  'vin santo': 0.4709658107828521,
#  'fresh yeast': 0.46622141805215034,
#  'allspice': 0.6952278328194269,
#  'ripe olives': 0.513984457195418,
#  'mutton': 0.44472575520982416,
#  'ginger paste': 0.5070577365449699,
#  'semolina': 0.7862068171973928,
#  'black cumin seeds': 0.326847649643046,
#  'plantains': 0.5359990864609337,
#  'pecans': 0.8343545593165409,
#  'piloncillo': 0.4395001794808375,
#  'vermouth': 0.4600058003239985,
#  'lemon wedge': 0.6579353663776508,
#  'caramel sauce': 0.6663529140786721,
#  'ice cream': 0.6322623322726687,
#  'coca-cola': 0.30309255488790515,
#  'salted peanuts': 0.5539411429034323,
#  'salted roast peanuts': 0.3033766024543217,
#  'shredded swiss cheese': 0.7934715744146806,
#  'large free range egg': 0.30752796630847756,
#  'spelt flour': 0.4219107085098121,
#  'cilantro': 0.5791358122574279,
#  'sweet chili sauce': 0.49068730124565785,
#  'rosemary': 0.6411357392395003,
#  'veal kidneys': 0.3606171721424897,
#  'beef broth': 0.6966149919355549,
#  'tarragon': 0.5658604124436446,
#  'asparagus': 0.6501107231150363,
#  'crusty loaf': 0.07168470006328716,
#  'fresh tomatoes': 0.6222959773139624,
#  'fennel': 0.5446633806201299,
#  'lime': 0.5577090751733256,
#  'chili pepper': 0.592189342275893,
#  'plain whole-milk yogurt': 0.5378699709985388,
#  'cilantro sprigs': 0.5146348865052383,
#  'chicken stock': 0.6816151092592302,
#  'spanish onion': 0.6361213696801218,
#  'leg of lamb': 0.5280917648947833,
#  'sage': 0.6967939228399211,
#  'black peppercorns': 0.5479398028125442,
#  'bacon pieces': 0.4265621535292124,
#  'cooked turkey': 0.610217296174425,
#  'Dutch-processed cocoa powder': 0.7136019710354907,
#  'fresh parsley leaves': 0.5620653088916916,
#  'coffee granules': 0.6127535692113726,
#  'chocolate chips': 0.7720478518775611,
#  'chicken base': 0.5951277776730864,
#  'mixed vegetables': 0.5152777170934137,
#  'puff pastry': 0.7254104104644548,
#  'rosemary sprigs': 0.5580315234192541,
#  'cold cut': 0.3929957275785907,
#  'chocolate wafer cookies': 0.2768614253573569,
#  'fresh cranberries': 0.6046904087457557,
#  'fresh mint': 0.603961358116082,
#  'green cardamom': 0.3963506041882066,
#  'lotus seeds': 0.3217380238158134,
#  'tarragon leaves': 0.48869603128277417,
#  'vegetable broth': 0.5794570053584966,
#  'artichok heart marin': 0.5317165856003923,
#  'baking potatoes': 0.7558713271450285,
#  'frozen artichoke hearts': 0.5767792693180698,
#  'white hominy': 0.44174959599518565,
#  'tomatillos': 0.5144264700724318,
#  'fresh marjoram': 0.5881100068366278,
#  'fresh thyme leaves': 0.6759100490928174,
#  'orange liqueur': 0.497224527429246,
#  'black tea leaves': 0.4830287202639779,
#  'cardamom pods': 0.47450573292833526,
#  'salted butter': 0.7173677051366966,
#  'wheat flour': 0.7591799609540923,
#  'mint': 0.5863794125159741,
#  'candy': 0.7715296140054535,
#  'smoked haddock': 0.43937463227520207,
#  'hot water': 0.8194813173265185,
#  'cocktail cherries': 0.4805631457925694,
#  'herbs': 0.6983338085026833,
#  'small red potato': 0.5917088357346124,
#  'cider vinegar': 0.7138108391456842,
#  'blueberry pie filling': 0.12124449426520335,
#  'powdered vanilla pudding mix': 0.5351282171775078,
#  'biscuit baking mix': 0.3983636012043796,
#  'whole kernel corn, drain': 0.524556052740447,
#  'whole peeled tomatoes': 0.49395376325611506,
#  "Campbell's Condensed Cheddar Cheese Soup": 0.10263370593373938,
#  'Pace Chunky Salsa': 0.17001627831381746,
#  'berries': 0.6332472222477658,
#  'Irish whiskey': 0.7151083405852319,
#  'fresh orange juice': 0.656681626114038,
#  'boneless pork shoulder': 0.5027161261520812,
#  'fish broth': 0.4369040887848911,
#  'corn kernel whole': 0.6410906424498514,
#  'pork blood': 0.4061929602949873,
#  'pinhead oatmeal': 0.2581026027721806,
#  'fresh pork fat': 0.5657817989931861,
#  'quick-cooking oats': 0.7617128923653679,
#  'peanut butter': 0.3461842915163301,
#  'basil leaves': 0.5933690633767515,
#  'goat cheese': 0.6557636891951093,
#  'canned black beans': 0.47700655286348514,
#  'prepared horseradish': 0.5786127869966052,
#  'crispy rice cereal': 0.4553423051334367,
#  'long grain white rice': 0.6241378825949463,
#  'boneless chicken breast halves': 0.5866373033704524,
#  'butternut squash': 0.6152028963995286,
#  'Italian cheese blend': 0.35568275387851567,
#  'chocolate candy bars': 0.46388637578815445,
#  'canned tuna': 0.38089058889523547,
#  'sushi rice': 0.3956741808400305,
#  'boudin': 0.18448049811018485,
#  'fresh green bean': 0.6277404096268298,
#  'buttermilk ranch dressing': 0.3865927606415201,
#  'wasabi powder': 0.38690513943496163,
#  'mint sauce': 0.31471654026949314,
#  'egg bread': 0.5793842053929535,
#  'frozen orange juice concentrate': 0.40082922062072185,
#  'syrup': 0.7041403361604018,
#  'masa': 0.5264797460428244,
#  'solid pack pumpkin': 0.679869622026163,
#  'crushed pineapple': 0.74552082225403,
#  'reduced fat cream cheese': 0.45739773276694806,
#  'deveined shrimp': 0.6434452876593426,
#  'cornbread': 0.667193959567565,
#  'bacon grease': 0.7434707218009556,
#  'ground sage': 0.6096771786719177,
#  'chicken thighs': 0.6761436401619084,
#  'dressing': 0.4836543628535654,
#  'salad': 0.6024762234170573,
#  'sprinkles': 0.799699491822805,
#  'fresh corn': 0.6580634390235411,
#  'espresso powder': 0.601520672190931,
#  'cookies': 0.47461979178815855,
#  'semi-sweet chocolate morsels': 0.8022217543364087,
#  'buckwheat flour': 0.7419101821414621,
#  'pineapple chunks': 0.48289669381069844,
#  'bell pepper': 0.5914745053698469,
#  'fish sauce': 0.47143736959279964,
#  'coarse ground mustard': 0.41454016579095415,
#  'dry vermouth': 0.6312284043123924,
#  'Bisquick Baking Mix': 0.26308879280484565,
#  "Old El Paso™ Thick 'n Chunky salsa": 0.30951249912339607,
#  'unbleached flour': 0.5689746132213134,
#  'orange rind': 0.6661435450195451,
#  'fenugreek seeds': 0.4445082937653294,
#  'chopped fresh thyme': 0.6230139635801201,
#  'smoked bacon': 0.5940575386789292,
#  'grated Gruyère cheese': 0.7286145155103565,
#  'shiitake': 0.5123378196165155,
#  'white mushrooms': 0.6507660632648143,
#  'unsweetened coconut milk': 0.4978790202355249,
#  'Madras curry powder': 0.5905137270127427,
#  'brewed coffee': 0.7638754356246967,
#  'cream cheese with chives': 0.41097580095565917,
#  'silver': 0.4095418290475847,
#  'light cream': 0.823740528895717,
#  'jaggery': 0.4292116432241961,
#  'fresh rosemary': 0.5921778739508755,
#  'beef stock cubes': 0.5032474392062405,
#  'banger': 0.5191897077333916,
#  'double-acting baking powder': 0.6310869555122975,
#  'pancetta': 0.5464041225585993,
#  'thin spaghetti': 0.47946194753181187,
#  'sliced mushrooms': 0.6937513114745183,
#  'cherry pie filling': 0.6328083094273568,
#  'Johnsonville Hot & Spicy Breakfast Links': 0.3051818977586775,
#  'shredded pepper jack cheese': 0.46402046619515863,
#  'pitted kalamata olives': 0.4442608342739344,
#  'plum tomatoes': 0.5963746669336508,
#  'decorating sugars': 0.7285832775043067,
#  'kidney beans': 0.5105837983815841,
#  'shredded lettuce': 0.41240443615278305,
#  'corn tortilla chips': 0.34103725873671553,
#  'chocolate syrup': 0.44066268647030354,
#  'Godiva Chocolate Liqueur': 0.006322919441422963,
#  'marshmallow vodka': 0.005850994386123736,
#  'marinara sauce': 0.5383763995702426,
#  'basil': 0.652772105710137,
#  'smoked paprika': 0.5720421399381009,
#  'potato flakes': 0.46759755008724035,
#  'portabello mushroom': 0.6227252841538129,
#  'feta cheese': 0.5657768434622342,
#  ...}

# %% [markdown]
# ## Computing the macro similarity graph

# %%
# Starting threshold
STARTING_THRESHOLD = 0.83

# Iwanthue palette for ten first communities
PALETTE = [
    '#c9587a',
    '#5dba5a',
    '#b65cbf',
    '#a3af44',
    '#747bc8',
    '#d49d43',
    '#4fbab7',
    '#d35238',
    '#588042',
    '#ac6f40'
]

# %%
similarity_graph = nx.Graph()

for ingredient, neighbors in MATRIX.items():
    for neighbor, cosine in neighbors.items():
        if cosine >= STARTING_THRESHOLD:
            similarity_graph.add_edge(ingredient, neighbor, cosine=cosine)

len(similarity_graph)
# Out:
# 1319

# %%
# Keeping only largest component
largest_component = set(max(nx.connected_components(similarity_graph), key=len))

for node in list(similarity_graph.nodes):
    if node not in largest_component:
        similarity_graph.remove_node(node)

# %%
# Community detection using the Louvain method
partition = community.best_partition(similarity_graph)

# Counting
communities_count = Counter()

for node, c in partition.items():
    communities_count[c] += 1
    
communities_colors = {}

i = 0
for c, _ in communities_count.most_common(10):
    communities_colors[c] = PALETTE[i]
    i += 1

# %%
# Styling
for node, attrs in similarity_graph.nodes(data=True):
    attrs['size'] = min(12, max(2, OCCURRENCES[node] / len(OCCURRENCES) * 6))
    attrs['color'] = communities_colors.get(partition[node], '#BBB')

# Display
Sigma(similarity_graph, height=1000)
# Out:
# Sigma(data={'nodes': [('romaine lettuce', {'size': 2, 'color': '#c9587a'}), ('grape tomatoes', {'size': 2, 'co…

# %% [markdown]
# ## Computing the micro similarity graphs

# %%
communities = [set() for i in range(len(communities_count))] 

for node, community in partition.items():
    communities[community].add(node)

# %%
SUBVECTORS = {}

for community in communities:
    for item in community:
        SUBVECTORS[item] = Counter(dict((key, count) for key, count in VECTORS[item].items() if key in community))
        
SUBVECTORS['milk']
# Out:
# Counter({'plain flour': 41,
#          'eggs': 734,
#          'green tomatoes': 13,
#          'yellow corn meal': 58,
#          'butter': 835,
#          'sugar': 598,
#          'ground cinnamon': 142,
#          'vanilla extract': 247,
#          'powdered sugar': 91,
#          'baking powder': 389,
#          'melted butter': 79,
#          'white sugar': 180,
#          'all-purpose flour': 791,
#          'chopped walnuts': 16,
#          'vanilla': 77,
#          'large egg yolks': 59,
#          'confectioners sugar': 68,
#          'softened butter': 15,
#          'buttermilk': 63,
#          'granulated sugar': 98,
#          'vegetable shortening': 22,
#          'egg yolks': 139,
#          'flour': 308,
#          'lard': 14,
#          'cream cheese': 70,
#          'shortening': 68,
#          'unsalted butter': 322,
#          'jam': 7,
#          'baking soda': 122,
#          'dried currants': 8,
#          'large eggs': 365,
#          'slivered almonds': 13,
#          'orange zest': 15,
#          'boiling water': 20,
#          'ground cloves': 20,
#          'ground allspice': 15,
#          'grated nutmeg': 37,
#          'bread': 33,
#          'egg whites': 51,
#          'margarine': 34,
#          'frozen pastry puff sheets': 10,
#          'ground nutmeg': 89,
#          'sweetened coconut flakes': 5,
#          'light brown sugar': 24,
#          'bananas': 33,
#          'cocoa powder': 13,
#          'peaches': 23,
#          'superfine sugar': 6,
#          'chives': 22,
#          'sliced almonds': 15,
#          'cornmeal': 81,
#          'sweetened condensed milk': 23,
#          'sharp cheddar cheese': 26,
#          'chopped almonds': 7,
#          'Grand Marnier': 2,
#          'cognac': 8,
#          'raisins': 65,
#          'dark rum': 14,
#          'warm water': 64,
#          'dough': 6,
#          'yeast': 39,
#          'walnuts': 3,
#          'raspberries': 6,
#          'fresh raspberries': 3,
#          'caster sugar': 24,
#          'whipping cream': 51,
#          'farmer cheese': 3,
#          'heavy cream': 107,
#          'masa harina': 5,
#          'cream of tartar': 36,
#          'molasses': 9,
#          'vegetable oil cooking spray': 8,
#          'pure vanilla extract': 20,
#          'bittersweet chocolate': 12,
#          'whipped cream': 18,
#          'sweet potatoes': 34,
#          'half & half': 20,
#          'evaporated milk': 20,
#          'instant espresso powder': 8,
#          'dark chocolate': 9,
#          'unsweetened cocoa powder': 36,
#          'refrigerated piecrusts': 8,
#          'firmly packed brown sugar': 16,
#          'whole wheat flour': 23,
#          'unflavored gelatin': 12,
#          'vanilla beans': 28,
#          'vegetable oil spray': 1,
#          'bacon drippings': 8,
#          'corn husks': 5,
#          'white cornmeal': 13,
#          'golden raisins': 23,
#          'almonds': 18,
#          'bread flour': 34,
#          'instant yeast': 22,
#          'bourbon whiskey': 14,
#          'almond extract': 23,
#          'mashed potatoes': 14,
#          'nutmeg': 50,
#          'grated lemon peel': 8,
#          'white flour': 11,
#          'lemon zest': 15,
#          'brandy': 13,
#          'chocolate': 7,
#          'cold milk': 3,
#          'apples': 16,
#          'cake flour': 32,
#          'light corn syrup': 8,
#          'dried tart cherries': 2,
#          'whole wheat pastry flour': 4,
#          'maple syrup': 9,
#          'white chocolate': 2,
#          'cream sweeten whip': 8,
#          'pecan halves': 7,
#          'mini marshmallows': 11,
#          'cherries': 3,
#          'glaze': 6,
#          'active dry yeast': 93,
#          'whole milk': 6,
#          'rum': 12,
#          'heavy whipping cream': 15,
#          'cream style corn': 22,
#          'chopped pecans': 39,
#          'dark brown sugar': 19,
#          'semisweet chocolate': 12,
#          'granny smith apples': 3,
#          'all purpose unbleached flour': 15,
#          'crème fraîche': 11,
#          'cranberries': 2,
#          'strawberries': 18,
#          'currant': 10,
#          'cocoa': 10,
#          'pistachios': 12,
#          'beaten eggs': 14,
#          'grated orange peel': 5,
#          'candied fruit': 7,
#          'yolk': 5,
#          'anise extract': 5,
#          'toasted pecans': 4,
#          'large egg whites': 8,
#          'ice water': 7,
#          'peach slices': 7,
#          'golden brown sugar': 1,
#          'dried cranberries': 5,
#          'blanched almonds': 7,
#          'semolina': 9,
#          'pecans': 4,
#          'Dutch-processed cocoa powder': 2,
#          'chocolate chips': 3,
#          'wheat flour': 4,
#          'hot water': 14,
#          'quick-cooking oats': 4,
#          'crushed pineapple': 4,
#          'semi-sweet chocolate morsels': 7,
#          'grated Gruyère cheese': 9,
#          'light cream': 5,
#          'semolina flour': 3,
#          'chop fine pecan': 4,
#          'lemon extract': 4,
#          'pastry': 8,
#          'prunes': 3,
#          'dates': 1,
#          'anise': 4,
#          'fresh blueberries': 4,
#          'vanilla ice cream': 10,
#          'grated orange': 7,
#          'blackberries': 7,
#          'frozen blueberries': 2,
#          'apricot preserves': 4,
#          'mascarpone': 6,
#          'dried apricot': 4,
#          'crystallized ginger': 1,
#          'sanding sugar': 2,
#          'mint sprigs': 5,
#          'unsweetened chocolate': 3,
#          'dark corn syrup': 2,
#          'milk chocolate': 2,
#          'marsala wine': 2,
#          'caraway seeds': 5,
#          'hazelnuts': 2,
#          'skim milk': 1,
#          'low-fat milk': 1,
#          'amaretto': 1,
#          'old-fashioned oats': 1})

# %%
SUBNORMS = {}
for ingredient, vector in SUBVECTORS.items():
    SUBNORMS[ingredient] = math.sqrt(sum(map(lambda x: x * x, vector.values())))
    
SUBNORMS['milk']
# Out:
# 1729.1422729203055

# %%
MATRICES = []

for community in tqdm_notebook(communities):
    m = defaultdict(dict)
    MATRICES.append(m)
    
    community = list(community)
    
    for i, kA in enumerate(community):
        nA = SUBNORMS[kA]
        A = SUBVECTORS[kA]
        
        for j in range(i + 1, len(community)):
            kB = community[j]
            nB = SUBNORMS[kB]
            B = SUBVECTORS[kB]
            
            s = sparse_dot_product(A, B) / (nA * nB)
            
            m[kA][kB] = s
            m[kB][kA] = s
# Out:
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))

# %%
similarity_graphs = []

SUB_THRESHOLD = 0.85

for i in range(len(communities)):
    m = MATRICES[i]
    g = nx.Graph()
    similarity_graphs.append(g)
    
    for ingredient, neighbors in m.items():
        for neighbor, cosine in neighbors.items():
            if cosine >= SUB_THRESHOLD:
                g.add_edge(ingredient, neighbor, cosine=cosine)

# %%
graph = similarity_graphs[1]

# Styling
for node, attrs in graph.nodes(data=True):
    attrs['size'] = min(12, max(2, OCCURRENCES[node] / len(OCCURRENCES) * 6))
    # attrs['color'] = communities_colors.get(partition[node], '#BBB')

# Display
Sigma(graph)
# Out:
# Sigma(data={'nodes': [('shallots', {'size': 2}), ('lemon wedge', {'size': 2}), ('fresh thyme leaves', {'size':…

# %%
Sigma(similarity_graph, height=1000)
# Out:
# Sigma(data={'nodes': [('romaine lettuce', {'size': 2, 'color': '#c9587a'}), ('grape tomatoes', {'size': 2, 'co…
