# %% [markdown]
# # SimSim

# %%
import json
import math
import networkx as nx
import community
from collections import defaultdict, Counter
from ipysigma import Sigma
from fog.metrics import sparse_dot_product
from tqdm import tqdm_notebook

# %% [markdown]
# ## Loading the recipes

# %%
with open('./recipes.json', 'r') as f:
    RECIPES = json.load(f)

for i, recipe in enumerate(RECIPES[0:2]):
    title = 'Recipe n°%i' % (i + 1)
    print(title)
    print('-' * len(title))
    
    for ingredient in recipe['ingredients']:
        print(ingredient)
        
    print()
print('...')
# Out:
# Recipe n°1
# ----------
# romaine lettuce
# black olives
# grape tomatoes
# garlic
# pepper
# purple onion
# seasoning
# garbanzo beans
# feta cheese crumbles
#
# Recipe n°2
# ----------
# plain flour
# ground pepper
# salt
# tomatoes
# ground black pepper
# thyme
# eggs
# green tomatoes
# yellow corn meal
# milk
# vegetable oil
#
# ...

# %% [markdown]
# ## Computing the similarity matrix

# %%
VECTORS = defaultdict(Counter)
OCCURRENCES = Counter()
for recipe in RECIPES:
    ingredients = recipe['ingredients']
    
    for i in range(len(ingredients)):
        A = ingredients[i]
        OCCURRENCES[A] += 1
        for j in range(i + 1, len(ingredients)):
            B = ingredients[j]
            
            VECTORS[A][B] += 1
            VECTORS[B][A] += 1
            
print(VECTORS['milk'].most_common(5))
print(OCCURRENCES['milk'])
print(len(VECTORS))
# Out:
# [('salt', 1354), ('butter', 835), ('all-purpose flour', 791), ('eggs', 734), ('sugar', 598)]
# 2263
# 6714

# %%
# Trimming
FREQ_THRESHOLD = 10

TO_DROP = set()

for i, c in OCCURRENCES.items():
    if c < FREQ_THRESHOLD:
        TO_DROP.add(i)
        
for i in TO_DROP:
    del VECTORS[i]
    
for i, v in VECTORS.items():
    for j in TO_DROP:
        if j in v:
            del v[j]

# %%
NORMS = {}
SUMS = {}
for ingredient, vector in VECTORS.items():
    NORMS[ingredient] = math.sqrt(sum(map(lambda x: x * x, vector.values())))
    SUMS[ingredient] = sum(vector.values())
    
NORMS['milk']
# Out:
# 2372.090428293154

# %%
# PMI computations
PMI = defaultdict(dict)
N_TOT = sum(sum(x for x in v.values()) for v in VECTORS.values()) / 2

for kA, A in tqdm_notebook(VECTORS.items()):
    nA = NORMS[kA]
    for kB, nab in A.items():
        B = VECTORS[kB]
        nB = NORMS[kB]
        # s = sparse_dot_product(A, B) / (nA * nB)
        s = math.log(nab * N_TOT / (SUMS[kA] * SUMS[kB]))
    
        if s > 1:
            PMI[kA][kB] = s
            PMI[kB][kA] = s
# Out:
# HBox(children=(IntProgress(value=0, max=2400), HTML(value='')))

# %%
MATRIX = defaultdict(dict)

for kA, A in tqdm_notebook(VECTORS.items()):
    nA = NORMS[kA]
    
    sA = sum(PMI[kA].values())
    
    for kB in A:
        B = VECTORS[kB]
        nB = NORMS[kB]
        
        ks = set(PMI[kA].keys()) & set(PMI[kB].keys())
        
        d = sum(min(PMI[kA][k], PMI[kB][k]) for k in ks)
            
        if sA <= 0:
            continue
        
        s = d / sA

        MATRIX[kA][kB] = s
        MATRIX[kB][kA] = s
# Out:
# HBox(children=(IntProgress(value=0, max=2400), HTML(value='')))

# %%
# Test
MATRIX['milk']
# Out:
# {'romaine lettuce': 0.010689893799720046,
#  'black olives': 0.009920202011598885,
#  'grape tomatoes': 0.035200993180384804,
#  'pepper': 0.0,
#  'purple onion': 0.009940609088630868,
#  'seasoning': 0.018862597448802604,
#  'garbanzo beans': 0.020470886631503423,
#  'feta cheese crumbles': 0.0,
#  'plain flour': 0.15878446278195724,
#  'ground pepper': 0.018072156829853518,
#  'tomatoes': 0.012116766586827275,
#  'thyme': 0.012441126191313111,
#  'eggs': 0.20021385263931726,
#  'green tomatoes': 0.04131111262329912,
#  'yellow corn meal': 0.10741547432302684,
#  'salt': 0.0,
#  'ground black pepper': 0.0,
#  'vegetable oil': 0.0,
#  'black pepper': 0.0,
#  'shallots': 0.0,
#  'cornflour': 0.05193249702476836,
#  'cayenne pepper': 0.0,
#  'onions': 0.0,
#  'garlic paste': 0.01984117885882317,
#  'butter': 0.43169513417798383,
#  'lemon juice': 0.03129286280260807,
#  'water': 0.0,
#  'chili powder': 0.0,
#  'passata': 0.007568403437154561,
#  'oil': 0.0157316747337883,
#  'ground cumin': 0.0,
#  'boneless chicken skinless thigh': 0.0,
#  'garam masala': 0.0,
#  'double cream': 0.04009762672947587,
#  'natural yogurt': 0.0,
#  'bay leaf': 0.02270486782002116,
#  'sugar': 0.13546292624456213,
#  'fresh ginger root': 0.01474516440230813,
#  'ground cinnamon': 0.07659416493855227,
#  'vanilla extract': 0.10713776243216871,
#  'ground ginger': 0.06287581572276155,
#  'powdered sugar': 0.099485546860757,
#  'baking powder': 0.16227188752815103,
#  'melted butter': 0.12269196578382936,
#  'matcha green tea powder': 0.03244803903645505,
#  'white sugar': 0.16370177230661812,
#  'all-purpose flour': 0.3497639467367507,
#  'chopped walnuts': 0.07325350915332642,
#  'vanilla': 0.09456182661021097,
#  'large egg yolks': 0.0626577756605695,
#  'corn starch': 0.055765551946323016,
#  'self rising flour': 0.08979620125831782,
#  'confectioners sugar': 0.12444578251865501,
#  'softened butter': 0.07568915607092637,
#  'food colouring': 0.05997915789676517,
#  'buttermilk': 0.16589421995265857,
#  'coarse salt': 0.0,
#  'steak': 0.014585675209250302,
#  'granulated sugar': 0.1055215839428398,
#  'vegetable shortening': 0.032916084002808,
#  'grated parmesan cheese': 0.015099771208912377,
#  'chopped celery': 0.008497800051835038,
#  'mustard powder': 0.025322166134905434,
#  'cod': 0.012449384332975082,
#  'minced onion': 0.019430688188248117,
#  'potatoes': 0.036447660425742344,
#  'red bell pepper': 0.0,
#  'chopped green bell pepper': 0.03908182537591297,
#  'old bay seasoning': 0.024053716533793453,
#  'dry bread crumbs': 0.06125897472574655,
#  'egg yolks': 0.1312237750363229,
#  'cinnamon sticks': 0.02368229097878975,
#  'flour': 0.2552827701612422,
#  'lard': 0.04260553944521075,
#  'frozen whipped topping': 0.07537995386118859,
#  'chocolate instant pudding': 0.01763791162735798,
#  'cream cheese': 0.10629297418587132,
#  'graham cracker crumbs': 0.04117871445371766,
#  'taco sauce': 0.018904861430544498,
#  'guacamole': 0.025340616638617988,
#  'garlic': 0.0,
#  'salsa verde': 0.0,
#  'shredded cabbage': 0.01197669216363371,
#  'dried oregano': 0.05353388941776858,
#  'kosher salt': 0.0,
#  'sweet onion': 0.029168181150762442,
#  'condiments': 0.0,
#  'avocado': 0.008419683356557761,
#  'pork shoulder roast': 0.0,
#  'tortillas': 0.018889676378222316,
#  'cumin': 0.052215347091998106,
#  'shortening': 0.12704721466285476,
#  'honey': 0.03002799604891074,
#  'unsalted butter': 0.0909433986511674,
#  'jam': 0.03769873019735314,
#  'baking soda': 0.13752444156066784,
#  'dried currants': 0.03898382287425489,
#  'sesame seeds': 0.012419798826418894,
#  'granulated garlic': 0.00782499315943019,
#  'chicken breasts': 0.056382286546454975,
#  'toasted sesame oil': 0.0,
#  'chicken broth': 0.05308753574818239,
#  'soy sauce': 0.0,
#  'vinegar': 0.04270602289052031,
#  'large eggs': 0.13825910462313173,
#  'sauce': 0.03934138193858829,
#  'cajun seasoning': 0.025023550957090808,
#  'shrimp': 0.019119829620484415,
#  'yellow mustard': 0.012387734275832899,
#  'ricotta cheese': 0.07752035231099526,
#  'slivered almonds': 0.04314352280723038,
#  'orange zest': 0.03372438112967485,
#  'orange juice': 0.03969812242855255,
#  'coriander seeds': 0.005841379532029983,
#  'boiling water': 0.06732429913243548,
#  'cauliflower': 0.006271626090777493,
#  'tamarind pulp': 0.0052066688096257625,
#  'coconut cream': 0.033348610423026365,
#  'chickpea flour': 0.006359363992944337,
#  'mustard seeds': 0.011114860696520823,
#  'ground cloves': 0.04470189320797012,
#  'eggplant': 0.0,
#  'plain breadcrumbs': 0.007750353299811334,
#  'diced tomatoes': 0.15632349531835105,
#  'tomato paste': 0.0,
#  'olive oil': 0.0,
#  'ground allspice': 0.045395226971124324,
#  'ground lamb': 0.0,
#  'dry red wine': 0.01921093335969385,
#  'grated nutmeg': 0.037298513858436154,
#  'boneless skinless chicken breasts': 0.08356858863552623,
#  'condensed cream of mushroom soup': 0.04040936260428501,
#  'fettuccine pasta': 0.0,
#  'broccoli': 0.023723233747567882,
#  'bread': 0.04194434840107892,
#  'lump crab meat': 0.00524697687710835,
#  'worcestershire sauce': 0.02910127525075519,
#  'mayonaise': 0.016704392217035794,
#  'egg whites': 0.12704740800670158,
#  'margarine': 0.08442725233870757,
#  'greek yogurt': 0.007158667646844665,
#  'chunky salsa': 0.016080230398595498,
#  'flour tortillas': 0.05702681584407116,
#  'shredded cheddar cheese': 0.09657442365649228,
#  'ground beef': 0.08668864275709354,
#  'beef bouillon granules': 0.013993624378729539,
#  'deli ham': 0.019689062589093403,
#  'fresh parsley': 0.08370273446107825,
#  'beef consomme': 0.00789566950637834,
#  'fresh mushrooms': 0.01000121174411514,
#  'Madeira': 0.011968599504931097,
#  'frozen pastry puff sheets': 0.003959844946562063,
#  'ground nutmeg': 0.1062243756608942,
#  'sweetened coconut flakes': 0.04459532576292169,
#  'light brown sugar': 0.048095699712808526,
#  'bananas': 0.05536734978924124,
#  'carrots': 0.0,
#  'baking mix': 0.03404855851375807,
#  'frozen peas': 0.08042999307017366,
#  'condensed cream of chicken soup': 0.03904766259085639,
#  'poultry seasoning': 0.060613085524062485,
#  'boneless skinless chicken breast halves': 0.04348649753358209,
#  'garlic powder': 0.07514372906091497,
#  'Kraft Grated Parmesan Cheese': 0.013957635221029127,
#  'pasta': 0.032140751330962385,
#  'peas': 0.020228113679289735,
#  'Philadelphia Cream Cheese': 0.034141229201427065,
#  'cocoa powder': 0.060424813360939286,
#  'peaches': 0.05215941129022604,
#  'cinnamon': 0.13518693670938178,
#  'parmesan cheese': 0.017359598616185006,
#  'superfine sugar': 0.04102212398913626,
#  'chives': 0.03339157299901372,
#  'sour cream': 0.10848448031179478,
#  'country ham': 0.05883445704368205,
#  'panko breadcrumbs': 0.02122103825105143,
#  'cooking spray': 0.008644237645601311,
#  'italian seasoning': 0.043500829464909276,
#  'garlic salt': 0.025303720898350954,
#  'chicken fingers': 0.02466195253524059,
#  'celery ribs': 0.011938325076079644,
#  'sliced almonds': 0.05541513861316206,
#  'water chestnuts': 0.012989422167642881,
#  'andouille sausage': 0.00639818156513328,
#  'green bell pepper': 0.0,
#  'cooked chicken': 0.03238051568685845,
#  'cream of mushroom soup': 0.018972049743442104,
#  'bread crumb fresh': 0.01721188654761419,
#  'black-eyed peas': 0.01066171777190184,
#  'low sodium chicken broth': 0.0,
#  'cornmeal': 0.05852258890498822,
#  'cold water': 0.13047619766852284,
#  'sweetened condensed milk': 0.07262016599967802,
#  'crushed tomatoes': 0.012542077515649076,
#  'parmigiano reggiano cheese': 0.016578038376262517,
#  'freshly ground pepper': 0.0258029978093674,
#  'flat leaf parsley': 0.0,
#  'yellow onion': 0.0,
#  'juice': 0.02013023845087728,
#  'fresh basil': 0.0,
#  'ground pork': 0.0,
#  'garlic cloves': 0.0,
#  'prosciutto': 0.011610203652554715,
#  'fresh oregano': 0.008094768020311132,
#  'gnocchi': 0.0,
#  'bread crumbs': 0.04491007205178139,
#  'green onions': 0.0,
#  'bacon': 0.06577469033064882,
#  'elbow macaroni': 0.03429531398133271,
#  'sharp cheddar cheese': 0.05496290160886659,
#  'gravy': 0.03638220047240211,
#  'peanut oil': 0.011797825087956466,
#  'onion powder': 0.05919200565570248,
#  'round steaks': 0.03088359907988564,
#  'chopped almonds': 0.04778907611933397,
#  'Grand Marnier': 0.03352229678604109,
#  'cognac': 0.03176450283133549,
#  'grated lemon zest': 0.033334268970715494,
#  'white pepper': 0.035452983303172134,
#  'fettucine': 0.0233593872684141,
#  'frozen broccoli': 0.01871619248785984,
#  'grating cheese': 0.03235124687007488,
#  'tapioca flour': 0.021668046779725215,
#  'raisins': 0.10866527779976856,
#  'toasted walnuts': 0.010718894490448352,
#  'orange': 0.017765876335817585,
#  'dark rum': 0.04967372922156957,
#  'dried fig': 0.019548106096189417,
#  'lemon': 0.03184633292271671,
#  'greens': 0.0,
#  'warm water': 0.1504616263263334,
#  'dough': 0.03006084342547506,
#  'cream': 0.0758692326387559,
#  'cake': 0.05068687877626652,
#  'yeast': 0.08303776050099963,
#  'walnuts': 0.029610940042131006,
#  'rose water': 0.04410133825923533,
#  'white vinegar': 0.01848266647748121,
#  'ketchup': 0.014683996837701928,
#  'ground turmeric': 0.0,
#  'chicken bouillon': 0.006836473310339086,
#  'coconut milk': 0.052001465515261934,
#  'ground paprika': 0.01240318900095746,
#  'curry powder': 0.0,
#  'ground almonds': 0.05977629564750704,
#  'raspberries': 0.019341126313317584,
#  'fresh raspberries': 0.023164760282958545,
#  'raspberry jam': 0.04494591082364781,
#  'biscuits': 0.059236575936564034,
#  'caster sugar': 0.07622045034803836,
#  'sponge cake': 0.036086644739032364,
#  'whipping cream': 0.08758503708981401,
#  'cottage cheese': 0.02623088068652105,
#  'farmer cheese': 0.04065419983069648,
#  'shrimp shells': 0.009546735281324189,
#  'white wine': 0.022858098429433767,
#  'grits': 0.0,
#  'heavy cream': 0.14696061703123153,
#  'fresh herbs': 0.012011183593005636,
#  'parmigiano-reggiano cheese': 0.0,
#  'bay leaves': 0.016592051333367244,
#  'sourdough bread': 0.010751659251595061,
#  'ground cayenne pepper': 0.008554792229798562,
#  'swiss cheese': 0.01634203261344669,
#  'frozen whole kernel corn': 0.02431446608514985,
#  'masa harina': 0.007346217545734124,
#  'rolled oats': 0.0582481398560747,
#  'golden syrup': 0.05697426149095987,
#  'granola': 0.0,
#  'mango': 0.0159538627838026,
#  'coconut': 0.034504152822895415,
#  'frozen mixed berries': 0.0166032515671726,
#  'ice': 0.012753183206801116,
#  'hot sauce': 0.0630686793417318,
#  'cream of tartar': 0.0711485743037451,
#  'molasses': 0.030135347531839368,
#  'vegetable oil cooking spray': 0.051468582800062904,
#  'fresh cilantro': 0.027616016525616457,
#  'chicken': 0.037635115630765055,
#  'lean ground beef': 0.06683446830509768,
#  'dry mustard': 0.030051125627181877,
#  'sweet paprika': 0.017254514968074057,
#  'white onion': 0.021425528782795935,
#  'dry sherry': 0.03349874303051448,
#  'white sandwich bread': 0.004886575597154415,
#  'mace': 0.030136181864925796,
#  'seasoned bread crumbs': 0.010067338283537015,
#  'minced garlic': 0.0,
#  'grated romano cheese': 0.0,
#  'quinoa': 0.01166816437649467,
#  'dried thyme': 0.0761717506039249,
#  'fat': 0.006061965272485547,
#  'dry white wine': 0.0,
#  'duck': 0.009045562656885482,
#  'toast': 0.0,
#  'low salt chicken broth': 0.006160839848885786,
#  'pure vanilla extract': 0.05273546171456778,
#  'bittersweet chocolate': 0.031331550474628864,
#  'whipped cream': 0.0648302061627872,
#  'mexican chocolate': 0.0,
#  'sweet potatoes': 0.09404439122258257,
#  'large garlic cloves': 0.0,
#  'half & half': 0.06441061731988072,
#  'evaporated milk': 0.12100386691109649,
#  'fresh lemon juice': 0.0,
#  'roasted red peppers': 0.01585640065508266,
#  'shredded mozzarella cheese': 0.05022898672686074,
#  'capers': 0.0,
#  'chopped tomatoes': 0.04487814629688378,
#  'chopped parsley': 0.017907357251794875,
#  'pitted black olives': 0.010310672825782513,
#  'sliced green onions': 0.013024178320485464,
#  'ground red pepper': 0.032318740443103365,
#  'cooked shrimp': 0.032716691805584314,
#  'coffee': 0.026885905174016875,
#  'white bread': 0.0390193225431365,
#  'red pepper flakes': 0.027890006233858643,
#  'ground white pepper': 0.01207514751597941,
#  'sherry vinegar': 0.0,
#  'toasted almonds': 0.008748693461460734,
#  'saffron threads': 0.020932141416557873,
#  'hungarian sweet paprika': 0.0,
#  'roasted hazelnuts': 0.011804518358077826,
#  'leeks': 0.015912107739188924,
#  'extra-virgin olive oil': 0.0,
#  'country bread': 0.0,
#  'quickcooking grits': 0.03790922621957222,
#  'barbecue sauce': 0.024471177678982707,
#  'instant espresso powder': 0.02681083975644906,
#  'dark chocolate': 0.05130635423913474,
#  'unsweetened cocoa powder': 0.06766580133415794,
#  'salsa': 0.040106377579929964,
#  'hot pepper sauce': 0.031985200206062006,
#  'chorizo sausage': 0.015075362385666211,
#  'shredded Monterey Jack cheese': 0.023659679341212336,
#  'corn tortillas': 0.008359733609994638,
#  'oregano': 0.017104053236855214,
#  'whole milk ricotta cheese': 0.017480336689609546,
#  'dried basil': 0.0,
#  'lasagna noodles': 0.04866416247195188,
#  'cream cheese, soften': 0.038720549586608755,
#  'green peas': 0.016338962397976466,
#  'salmon fillets': 0.010233584517598582,
#  'cooking oil': 0.03620482921919023,
#  'chopped fresh chives': 0.03016584318598412,
#  'cayenne': 0.04442169722914264,
#  'boiling potatoes': 0.005468102388605591,
#  'creole seasoning': 0.045380521678551014,
#  'cabbage': 0.03841595602817009,
#  'corn': 0.0502646640154913,
#  'monterey jack': 0.06272427516456694,
#  'red pepper': 0.03386791134233275,
#  'green pepper': 0.056006170856293204,
#  'noodles': 0.006418264101694855,
#  'refrigerated piecrusts': 0.03469678198250112,
#  'firmly packed brown sugar': 0.037679437128705,
#  "I Can't Believe It's Not Butter!® Spread": 0.0,
#  'whole wheat flour': 0.07088102551601917,
#  'medium eggs': 0.07694034113456236,
#  'unflavored gelatin': 0.030517094569214424,
#  'vanilla beans': 0.0320203831807534,
#  'Frangelico': 0.018694640283839457,
#  'vegetable oil spray': 0.01606950456842574,
#  'sirloin steak': 0.009337686829542504,
#  'bacon drippings': 0.015725735790589845,
#  'ham': 0.012565119551609983,
#  'dijon mustard': 0.028541117527837705,
#  'plain yogurt': 0.04243903718050961,
#  'radishes': 0.0,
#  'fresh dill': 0.018426854892073134,
#  'cucumber': 0.0,
#  'corn husks': 0.0,
#  'cotija': 0.0,
#  'lime wedges': 0.0,
#  'chopped cilantro fresh': 0.029963272727679107,
#  'white cornmeal': 0.06595058980399407,
#  'diced onions': 0.03225116412416522,
#  'cheddar cheese': 0.07109823992273301,
#  'green chilies': 0.022429900055772008,
#  'paneer': 0.015626776651084175,
#  'chopped cilantro': 0.08908797142996025,
#  'amchur': 0.013335822336186383,
#  'coriander powder': 0.015382542315579706,
#  'tumeric': 0.010520984936780936,
#  'vegetables': 0.012155734768475458,
#  'ginger': 0.0,
#  'cumin seed': 0.0,
#  'asafetida': 0.0,
#  'liqueur': 0.02108946923573742,
#  'golden raisins': 0.06320122142112308,
#  'ranch dressing': 0.015800638153112178,
#  'boneless chuck roast': 0.0,
#  'chili sauce': 0.0062847481072659936,
#  'red curry paste': 0.0,
#  'cilantro leaves': 0.03409782983842793,
#  'lamb': 0.005404945767243944,
#  'pork sausages': 0.03609168846006612,
#  'jalapeno chilies': 0.1034617268137764,
#  'taco seasoning': 0.052025734400177756,
#  'jack cheese': 0.028213243932800395,
#  'macaroni': 0.02282667939464311,
#  'shredded sharp cheddar cheese': 0.06623856105597219,
#  'pork': 0.03349323746529844,
#  'ground mustard': 0.02426825774704401,
#  'almonds': 0.06348446724010372,
#  'dried parsley': 0.010415345870813322,
#  'self-rising cornmeal': 0.0691545257153599,
#  'catfish fillets': 0.014914378587393043,
#  'seasoning salt': 0.0381047717670633,
#  'bread flour': 0.09459672043085153,
#  'instant yeast': 0.050404739910471216,
#  'bourbon whiskey': 0.05140179128340464,
#  'cooked ham': 0.027474489236723184,
#  'powdered milk': 0.07189316904536897,
#  'ground cardamom': 0.06308705947908612,
#  'maida flour': 0.03258954389899003,
#  'ghee': 0.032088102166581235,
#  'soft-wheat flour': 0.04646585252182231,
#  'almond extract': 0.06500017647019413,
#  'mashed potatoes': 0.032686047196767064,
#  'spring onions': 0.017680804143338415,
#  'nutmeg': 0.09047510374248169,
#  'grated lemon peel': 0.011697060822597563,
#  'white flour': 0.06669674220212309,
#  'lemon zest': 0.05633718724320757,
#  'strong white bread flour': 0.029674348323952774,
#  'vanilla essence': 0.057045670089660425,
#  'glutinous rice flour': 0.037077459475780415,
#  'frozen corn': 0.017192957020384238,
#  'brandy': 0.037257794092893134,
#  'chocolate': 0.022159664423846606,
#  'silken tofu': 0.0,
#  'cold milk': 0.05107314167764625,
#  'white rice': 0.03511951953573295,
#  'green chile': 0.05103036958206013,
#  'chile powder': 0.009322684468562341,
#  'corn kernels': 0.06531570547727153,
#  'extra sharp cheddar cheese': 0.040412121625732225,
#  'salt and ground black pepper': 0.018082221480062142,
#  'crust': 0.029214027947197387,
#  'clams': 0.0,
#  'fontina cheese': 0.0048865484147289,
#  'green bell pepper, slice': 0.0,
#  'poppy seeds': 0.05003978679608182,
#  'vanilla wafers': 0.043067967226320614,
#  'brown sugar': 0.09238602675248712,
#  'sausages': 0.03503672396641068,
#  'mustard': 0.006983656489818668,
#  'Guinness Beer': 0.02661943800657189,
#  'apples': 0.03337085886689856,
#  'cake flour': 0.07867939539799197,
#  'coconut extract': 0.03886595913149438,
#  'flaked coconut': 0.0568057195933874,
#  'light corn syrup': 0.049642598891400616,
#  'shell pasta': 0.0,
#  'paprika': 0.0,
#  'dry yeast': 0.08414987611908276,
#  'kirsch': 0.04281503763999996,
#  'dried tart cherries': 0.009845443518422438,
#  'mint leaves': 0.024274259551882,
#  'cardamom': 0.03327968428992146,
#  'peppercorns': 0.01587086609616756,
#  'yoghurt': 0.03420047825898908,
#  'star anise': 0.008257862639258403,
#  'basmati rice': 0.018623626691294005,
#  'clove': 0.007746018551059354,
#  'Biryani Masala': 0.0,
#  'saffron': 0.03527266017325911,
#  'whole wheat pastry flour': 0.027033610971082676,
#  'maple syrup': 0.0420221638816516,
#  'cream of chicken soup': 0.035862314876068835,
#  'part-skim mozzarella cheese': 0.0,
#  'tortilla chips': 0.05043491741742402,
#  'shredded parmesan cheese': 0.030875502810371415,
#  'peeled shrimp': 0.0080965642460744,
#  'white chocolate': 0.02503325677709796,
#  'french bread': 0.024573148530446544,
#  'crawfish': 0.018828908416758168,
#  'chopped onion': 0.07846420796765226,
#  'black tea': 0.01927482632398126,
#  'fresh ginger': 0.0,
#  'cream sweeten whip': 0.030380424069024307,
#  'tea bags': 0.0051897921291201255,
#  'pecan halves': 0.05765837449021441,
#  'mini marshmallows': 0.05743110300846208,
#  'fruit': 0.03966259305183305,
#  'cherries': 0.03335666062108029,
#  'glaze': 0.07199855149504343,
#  'active dry yeast': 0.1254838604542616,
#  'whole milk': 0.1409658526224043,
#  'canola oil': 0.0,
#  'pistachio nuts': 0.04295541837497789,
#  'Tabasco Pepper Sauce': 0.02110756838919026,
#  'crepes': 0.02063491659570145,
#  'dried tarragon leaves': 0.01082149037264917,
#  'finely chopped onion': 0.041630940652122396,
#  'unbaked pie crusts': 0.02764166572113402,
#  'beef': 0.0,
#  'idaho potatoes': 0.00739865591240543,
#  'haricots verts': 0.0,
#  'sea salt': 0.014457557436524614,
#  'rib eye steaks': 0.0,
#  'red wine': 0.010684525795403124,
#  'baby carrots': 0.007664776995471452,
#  'chervil': 0.0,
#  'port': 0.01165932083463885,
#  'corn mix muffin': 0.012156728596902177,
#  'shredded extra sharp cheddar cheese': 0.044636821429327254,
#  'black beans': 0.034267916437658925,
#  'diced green chilies': 0.0205426480377258,
#  'cornbread mix': 0.0380882180557177,
#  'rum': 0.05295717987857987,
#  'heavy whipping cream': 0.06262432184608684,
#  'cherry tomatoes': 0.005295103396655141,
#  'sharp white cheddar cheese': 0.022391682744930974,
#  'Sriracha': 0.015867326364022723,
#  'thick-cut bacon': 0.0,
#  'nuts': 0.03455245257117622,
#  'cream style corn': 0.05932358777913894,
#  'enchilada sauce': 0.024111740004991142,
#  'chopped pecans': 0.10059254925135257,
#  'fresh mozzarella': 0.004749773086148093,
#  'fresh curry leaves': 0.0,
#  'ground coriander': 0.0,
#  'frozen chopped spinach': 0.024457884987183254,
#  'chile pepper': 0.006997124338811788,
#  'dark brown sugar': 0.04812350526237169,
#  'spicy brown mustard': 0.015051034183327388,
#  'port wine': 0.040619693203893054,
#  'fresh sage': 0.004847816589708377,
#  'chicken bouillon granules': 0.03132236135812637,
#  'fresh thyme': 0.018225979170571265,
#  'celery': 0.032818236993615975,
#  'pimentos': 0.018495008698023285,
#  'rotisserie chicken': 0.007599762478745323,
#  'doritos': 0.0,
#  'shredded cheese': 0.04990380429229676,
#  'soy milk': 0.0425072290554144,
#  'gluten': 0.0372375336360273,
#  'japanese rice': 0.0,
#  'parsley': 0.03254030092017484,
#  'minced beef': 0.008113686583448411,
#  'sweet corn': 0.006424936843263217,
#  'semisweet chocolate': 0.052595282526846046,
#  'condensed milk': 0.06993674573886784,
#  'chips': 0.016993625218743497,
#  'granny smith apples': 0.014060664637418995,
#  'vidalia onion': 0.040476776729871315,
#  'queso fresco': 0.0058401106171333044,
#  'all purpose unbleached flour': 0.0621174333678043,
#  'cracked black pepper': 0.025345448169491972,
#  'crème fraîche': 0.038242918473789245,
#  'rolls': 0.04487825774159598,
#  'green cabbage': 0.005134825708209331,
#  'balsamic vinegar': 0.007218413429201856,
#  'kale': 0.0,
#  'fine sea salt': 0.019269561066869025,
#  'russet potatoes': 0.018198505254073873,
#  'fusilli': 0.006835319573670467,
#  'yellow bell pepper': 0.017408639577054442,
#  'blue cheese': 0.02236952653408186,
#  'cheese soup': 0.013744329548112316,
#  'cheese': 0.05702729984669696,
#  'serrano': 0.0,
#  'cranberries': 0.02934342529453248,
#  'low-fat ricotta cheese': 0.0,
#  'tomato purée': 0.023141073543123086,
#  'freshly grated parmesan': 0.011379105958964292,
#  'pumpkin': 0.017067353702581542,
#  'baby spinach': 0.0,
#  'fennel bulb': 0.0,
#  'fresh chives': 0.022116317102710906,
#  'frozen peas and carrots': 0.009808097023291693,
#  'strawberries': 0.03602701871197612,
#  'lean minced beef': 0.00824732014033039,
#  'beef stock': 0.017647957681772675,
#  'penne pasta': 0.01803443585539858,
#  'ground turkey': 0.04356144652766655,
#  'light cream cheese': 0.020444435239388607,
#  'chipotles in adobo': 0.0,
#  'lemon peel': 0.02323442192914965,
#  'hard-boiled egg': 0.008620238761074896,
#  'dried salted codfish': 0.0,
#  'zucchini': 0.022333561576871577,
#  'vermicelli': 0.009589045838169039,
#  'citron': 0.07834685113022428,
#  'currant': 0.03672530309385744,
#  'lemon rind': 0.01701810851415394,
#  'brewed espresso': 0.02990717221459662,
#  'beef drippings': 0.04716368454653524,
#  'cocoa': 0.06251608970995028,
#  'ground meat': 0.0,
#  'seeds': 0.022486440152933235,
#  'chili flakes': 0.00469955367434334,
#  'chiles': 0.01619146273601295,
#  'curry': 0.0,
#  'serrano chilies': 0.005811696865868216,
#  'pico de gallo': 0.013721142555297973,
#  'rigatoni': 0.0,
#  'nonstick spray': 0.039489118070965744,
#  'asadero': 0.0,
#  'sausage links': 0.0,
#  'savory': 0.00804689206521428,
#  'reduced sodium chicken broth': 0.0041493686847374825,
#  'collard greens': 0.015205261650754948,
#  'medium shrimp uncook': 0.0,
#  'lemon pepper': 0.015624439332447785,
#  'ham steak': 0.03294167713312619,
#  'marmite': 0.007936416822883577,
#  'graham cracker crusts': 0.054664192503253474,
#  'lime zest': 0.024021201876354162,
#  'whipped topping': 0.04629464809198175,
#  'key lime juice': 0.04145059524800551,
#  'breakfast sausages': 0.03094330344331255,
#  'pistachios': 0.017930482073887873,
#  'asparagus spears': 0.004578284279188299,
#  'beaten eggs': 0.05861284824659017,
#  'orange peel': 0.009942822990837213,
#  'grated orange peel': 0.021948791131837377,
#  'chocolate shavings': 0.04144567655410117,
#  'candied fruit': 0.06876242057630873,
#  'yellow cake mix': 0.05250310064597185,
#  'vanilla instant pudding': 0.057368836027911,
#  'Nilla Wafers': 0.08059449332792876,
#  'grated coconut': 0.014549643613729618,
#  'Mexican cheese blend': 0.03492362075587736,
#  'red enchilada sauce': 0.01776433062200919,
#  'cashew nuts': 0.024699069380508705,
#  'french fried onions': 0.037932616633305896,
#  'chicken pieces': 0.011127194991807322,
#  'red chili powder': 0.01297062007513183,
#  'curds': 0.027032872305906765,
#  'button mushrooms': 0.010792281134245761,
#  'crabmeat': 0.020442682598146175,
#  'yolk': 0.028809486512531464,
#  'pie shell': 0.05968359106683026,
#  'curry leaves': 0.02098310881906922,
#  'sweetener': 0.006482987937534958,
#  'egg noodles, cooked and drained': 0.0203950309648771,
#  'anise extract': 0.06301748787279482,
#  'udon': 0.0,
#  'peanuts': 0.01127720719831136,
#  'crushed red pepper flakes': 0.012571155406554171,
#  'dark sesame oil': 0.0,
#  'chopped fresh mint': 0.0,
#  'chunky peanut butter': 0.0,
#  'rice vinegar': 0.0,
#  'beansprouts': 0.013718539383974498,
#  'bacon slices': 0.017369815512876183,
#  'smoked turkey': 0.008654889017885522,
#  'sliced ham': 0.005394390927650987,
#  'penne': 0.011112605932831013,
#  'marinade': 0.005199039098951044,
#  'jamaican jerk season': 0.00817862144060061,
#  'lime juice': 0.014601510067986104,
#  'pineapple juice': 0.0045040264041173285,
#  'toasted pecans': 0.02263490311012564,
#  'greek style plain yogurt': 0.01304780959569874,
#  'roast red peppers, drain': 0.0,
#  'linguine': 0.008746186416189903,
#  'oven-ready lasagna noodles': 0.005884075985405577,
#  'boneless chicken breast': 0.0426582499281373,
#  'ground thyme': 0.0,
#  'apple cider': 0.006341278236436545,
#  'dried fruit': 0.048931587559940946,
#  'part-skim ricotta cheese': 0.01945275160906702,
#  'green beans': 0.006297229295998825,
#  'large egg whites': 0.03800691599778128,
#  'gruyere cheese': 0.014715337265439278,
#  'chopped ham': 0.01649017025048592,
#  'American cheese': 0.05256054505671886,
#  'pickled jalapenos': 0.017594505388528452,
#  'ice water': 0.03656948972026841,
#  'dill': 0.007404991525587789,
#  'mushrooms': 0.010671150500875456,
#  'long-grain rice': 0.008599147693250259,
#  'smoked salmon': 0.017581588601792413,
#  'cheese tortellini': 0.0,
#  'fresh asparagus': 0.006784657168201041,
#  'coffee liqueur': 0.03435846275429814,
#  'crushed ice': 0.003436045101765713,
#  'trout fillet': 0.0,
#  'parsley sprigs': 0.015884882279118093,
#  'couscous': 0.007191577251033277,
#  'corn flour': 0.045443301236130246,
#  'white cheddar cheese': 0.0440986847518809,
#  'rapid rise yeast': 0.05783257369841439,
#  'Italian bread': 0.01819150678225626,
#  'peach slices': 0.02327565192706638,
#  'cod fillets': 0.007017236915240554,
#  'panko': 0.01237166566636019,
#  'pepperoni slices': 0.011815701505424622,
#  'tomato sauce': 0.043930522715028765,
#  'mozzarella cheese': 0.034839733168216466,
#  'poblano peppers': 0.014884027026728247,
#  'tart apples': 0.011390270509898047,
#  'bread slices': 0.013510111265199836,
#  'min': 0.02659268557857839,
#  'liquid': 0.01985866559499996,
#  'roasted cashews': 0.0188091623322991,
#  'spices': 0.004955971213200324,
#  'lamb shoulder': 0.014698776928772613,
#  'green cardamom pods': 0.010358726137346912,
#  'canned tomatoes': 0.00818355335903431,
#  'rice': 0.041251584422444504,
#  'low-fat plain yogurt': 0.006670123278223074,
#  'serrano chile': 0.007616135728960063,
#  'pasta sauce': 0.02550881517594308,
#  'spaghetti': 0.028176568989941093,
#  'crumbles': 0.0,
#  'scallions': 0.0,
#  'cream sherry': 0.025462362024912477,
#  'preserves': 0.04112072526522188,
#  'provolone cheese': 0.011955167946764834,
#  'golden brown sugar': 0.016158474806859335,
#  'pie crust': 0.03559285923164194,
#  'spinach': 0.012828320068780671,
#  'jeera': 0.006715872285468254,
#  'asafoetida': 0.0,
#  'coriander': 0.0,
#  'minced ginger': 0.005415210854882573,
#  'kasuri methi': 0.009156922856434315,
#  'rutabaga': 0.0,
#  'rotel tomatoes': 0.008556584671613866,
#  'pepper sauce': 0.025894163739532607,
#  'fresh coriander': 0.0059699581950003995,
#  'clear honey': 0.005599784875682995,
#  'chickpeas': 0.009325997493180053,
#  'dried cranberries': 0.029930599137733924,
#  'shelled pistachios': 0.00620569882231065,
#  'squash': 0.0,
#  'harissa paste': 0.0,
#  'blanched almonds': 0.0446984982635682,
#  'fresh spinach': 0.006560068930594264,
#  'phyllo pastry': 0.008286636230851836,
#  'crushed red pepper': 0.015151459894965882,
#  'grated jack cheese': 0.02285135079930267,
#  'allspice': 0.04068244996271501,
#  'ripe olives': 0.026125820012673454,
#  'mutton': 0.0,
#  'ginger paste': 0.0,
#  'semolina': 0.05785820403654562,
#  'plantains': 0.0047270422771801025,
#  'pecans': 0.04052552638180884,
#  'piloncillo': 0.0063230145814873115,
#  'lemon wedge': 0.024293260659863265,
#  'caramel sauce': 0.03993806024549076,
#  'ice cream': 0.028928986969651273,
#  'coca-cola': 0.01987345447022932,
#  'salted peanuts': 0.006991842153152607,
#  'salted roast peanuts': 0.0,
#  'shredded swiss cheese': 0.02548288182366897,
#  'large free range egg': 0.02289622338527081,
#  'cilantro': 0.0,
#  'sweet chili sauce': 0.0056502136794061185,
#  'rosemary': 0.011784062114677236,
#  'beef broth': 0.029650568400307612,
#  'tarragon': 0.004942733685961828,
#  'asparagus': 0.02283056793098607,
#  'fresh tomatoes': 0.0,
#  'fennel': 0.0037323023368504814,
#  'lime': 0.0,
#  'chili pepper': 0.010941229830832658,
#  'plain whole-milk yogurt': 0.006845745443388287,
#  'cilantro sprigs': 0.011858463694341436,
#  'chicken stock': 0.0,
#  'spanish onion': 0.0,
#  'leg of lamb': 0.012384635475844766,
#  'sage': 0.013195799299517582,
#  'black peppercorns': 0.006293427735285186,
#  'cooked turkey': 0.023134941152259246,
#  'Dutch-processed cocoa powder': 0.03886817644156875,
#  'fresh parsley leaves': 0.0,
#  'coffee granules': 0.0410172102372441,
#  'chocolate chips': 0.050112961117005694,
#  'chicken base': 0.01926307813813014,
#  'mixed vegetables': 0.0,
#  'puff pastry': 0.020162063277123752,
#  'rosemary sprigs': 0.008992349893930343,
#  'fresh cranberries': 0.013883606626262887,
#  'fresh mint': 0.00468557802157469,
#  'green cardamom': 0.024611682271226728,
#  'vegetable broth': 0.0,
#  'artichok heart marin': 0.005125716115558795,
#  'baking potatoes': 0.021206172041648527,
#  'frozen artichoke hearts': 0.0,
#  'white hominy': 0.0,
#  'tomatillos': 0.011371965991355575,
#  'fresh marjoram': 0.009061407457677187,
#  'fresh thyme leaves': 0.009275504251147142,
#  'orange liqueur': 0.015376378321673585,
#  'black tea leaves': 0.0063835330219517965,
#  'cardamom pods': 0.0301724262888764,
#  'salted butter': 0.052859929459492916,
#  'wheat flour': 0.043122585161833586,
#  'mint': 0.015406249479432916,
#  'candy': 0.04999105973342417,
#  'hot water': 0.054380829086670475,
#  'cocktail cherries': 0.023056213967904717,
#  'herbs': 0.024027073756014747,
#  'small red potato': 0.0,
#  'cider vinegar': 0.0,
#  'whole kernel corn, drain': 0.019984134987832018,
#  'whole peeled tomatoes': 0.007278124944469192,
#  'berries': 0.022798873833368424,
#  'Irish whiskey': 0.017113077617815078,
#  'fresh orange juice': 0.003986036464189876,
#  'boneless pork shoulder': 0.005373294444492214,
#  'corn kernel whole': 0.02246507933529081,
#  'fresh pork fat': 0.0,
#  'quick-cooking oats': 0.051291204006680184,
#  'peanut butter': 0.011325081145077897,
#  'basil leaves': 0.005030610792306014,
#  'goat cheese': 0.008758810223159283,
#  'canned black beans': 0.017957442296596852,
#  'prepared horseradish': 0.014896682257961726,
#  'long grain white rice': 0.006770682605511786,
#  'boneless chicken breast halves': 0.026561653850357032,
#  'butternut squash': 0.013750802907250807,
#  'sushi rice': 0.0,
#  'fresh green bean': 0.011352836036090249,
#  'wasabi powder': 0.0,
#  'frozen orange juice concentrate': 0.012973964634239778,
#  'syrup': 0.021451399844034314,
#  'masa': 0.0,
#  'solid pack pumpkin': 0.00877273747838471,
#  'crushed pineapple': 0.04915735224085531,
#  'reduced fat cream cheese': 0.00953827267278796,
#  'deveined shrimp': 0.014217969677613199,
#  'cornbread': 0.030495113949153673,
#  'bacon grease': 0.011584108515007917,
#  'ground sage': 0.030894373585860373,
#  'chicken thighs': 0.008976451402747505,
#  'dressing': 0.017270141389119385,
#  'salad': 0.009368695597371536,
#  'sprinkles': 0.056908562050554924,
#  'fresh corn': 0.011169976723050383,
#  'cookies': 0.05238673228662074,
#  'semi-sweet chocolate morsels': 0.0525828433634608,
#  'buckwheat flour': 0.095590573008375,
#  'pineapple chunks': 0.020805287628758308,
#  'bell pepper': 0.009150873113368646,
#  'fish sauce': 0.0,
#  'dry vermouth': 0.012031513432404392,
#  'orange rind': 0.02304569181486102,
#  'fenugreek seeds': 0.0,
#  'chopped fresh thyme': 0.024757289480975796,
#  'smoked bacon': 0.0,
#  'grated Gruyère cheese': 0.016550706674843766,
#  'shiitake': 0.0046754666654986185,
#  'white mushrooms': 0.00831381761861913,
#  'unsweetened coconut milk': 0.0,
#  'Madras curry powder': 0.0,
#  'brewed coffee': 0.041320680071110116,
#  'light cream': 0.0388378275882582,
#  'jaggery': 0.0,
#  'fresh rosemary': 0.00628946354503313,
#  'beef stock cubes': 0.015077911176025798,
#  'double-acting baking powder': 0.04663462869048444,
#  'pancetta': 0.0,
#  'thin spaghetti': 0.0,
#  'sliced mushrooms': 0.01603511648256201,
#  'shredded pepper jack cheese': 0.018065686219865016,
#  'pitted kalamata olives': 0.00507850642868128,
#  'plum tomatoes': 0.0,
#  'kidney beans': 0.01658808532528955,
#  'shredded lettuce': 0.035034249413584496,
#  'corn tortilla chips': 0.007904614845403177,
#  'chocolate syrup': 0.016693888304807877,
#  'marinara sauce': 0.02775956192045414,
#  'basil': 0.028976234552126293,
#  'smoked paprika': 0.012451725342036129,
#  'portabello mushroom': 0.00470848349171961,
#  'feta cheese': 0.004606141536104639,
#  'whole wheat tortillas': 0.0,
#  'candied orange peel': 0.03317542188769059,
#  'rotelle': 0.01714089018235696,
#  'semolina flour': 0.03436597532945134,
#  'shredded coconut': 0.037294452361396724,
#  'sun-dried tomatoes': 0.02561659410703681,
#  'romano cheese': 0.016989757970809715,
#  'bow-tie pasta': 0.012258701871097339,
#  'parsley leaves': 0.014747514037255252,
#  'manicotti shells': 0.009093349472120114,
#  'yukon gold potatoes': 0.005363295785846547,
#  'mustard greens': 0.007640539964482464,
#  'roasted garlic': 0.0195537843703066,
#  'saltines': 0.021866636050779674,
#  'chop fine pecan': 0.025798773925629546,
#  'frozen bread dough': 0.010907388686817841,
#  'lemon extract': 0.06325130770434842,
#  'sunflower oil': 0.009290071694884092,
#  'yellow food coloring': 0.05035995840365456,
#  'italian sausage': 0.0288872137676373,
#  'table salt': 0.041484979726231726,
#  'broccoli rabe': 0.0,
#  'pesto sauce': 0.018600164761738685,
#  'sherry wine': 0.035407230507271764,
#  'toasted slivered almonds': 0.021694826071504136,
#  'ladyfingers': 0.025326064334055806,
#  'clarified butter': 0.03243893867331411,
#  'kalamata': 0.0,
#  'rice flour': 0.019836077571863425,
#  'sausage casings': 0.005166198130849434,
#  'fontina': 0.006046209010999841,
#  'dried minced onion': 0.005305652505307571,
#  'cremini mushrooms': 0.0,
#  'pastry': 0.03338295231902461,
#  'mild cheddar cheese': 0.02337989469297531,
#  'whole almonds': 0.0180548343970973,
#  'chicken livers': 0.006044197505643416,
#  'free range egg': 0.07130356287071637,
#  'celery salt': 0.034195343448041544,
#  'colby jack cheese': 0.03588004975459116,
#  'hungarian paprika': 0.0,
#  'medium shrimp': 0.0288999301665518,
#  'veal cutlets': 0.0,
#  'stewed tomatoes': 0.018719471641215586,
#  'whiskey': 0.046346895161960514,
#  'italian tomatoes': 0.007311345085099231,
#  'crumbled gorgonzola': 0.00970660126081302,
#  'instant coffee': 0.023809262015764276,
#  'sake': 0.0,
#  'sesame oil': 0.0,
#  'oyster sauce': 0.007733230416620618,
#  'chinese cabbage': 0.010960450113630137,
#  'single crust pie': 0.02556685235043397,
#  'sherry': 0.03370177131273017,
#  'ground chipotle chile pepper': 0.0,
#  'pecorino romano cheese': 0.01851989411436648,
#  'ground veal': 0.0,
#  'marjoram': 0.014357063035679967,
#  'pork shoulder': 0.004556371937272162,
#  'pastry dough': 0.026413586152704727,
#  'dri leav thyme': 0.0056070960993686485,
#  'beef tenderloin steaks': 0.0,
#  'soft fresh goat cheese': 0.005369330439064621,
#  'medium dry sherry': 0.0405006581264508,
#  'crab meat': 0.009852710359118439,
#  'jumbo pasta shells': 0.014058951262693034,
#  'filet': 0.0,
#  'orzo pasta': 0.0,
#  'roma tomatoes': 0.02368462667338148,
#  'tequila': 0.005988386946318248,
#  'raw almond': 0.011601063110125383,
#  'raw cashews': 0.0,
#  'manchego cheese': 0.0210200439422114,
#  'anchovy fillets': 0.0,
#  'black sesame seeds': 0.004516233909407867,
#  'boneless chop pork': 0.008995014892495837,
#  'brown rice': 0.0,
#  'mirin': 0.004149045050519374,
#  'miso': 0.0,
#  'boiled eggs': 0.0,
#  'armagnac': 0.009839371927097171,
#  'fennel seeds': 0.0,
#  'prunes': 0.005442038355719644,
#  'dates': 0.03999454086461611,
#  'white sesame seeds': 0.008724285839339976,
#  'fresh lime': 0.0,
#  'pork chops': 0.014305496007259513,
#  'ras el hanout': 0.0,
#  'leaves': 0.004638385020450044,
#  'low sodium beef broth': 0.0073515879673286405,
#  'coarse sea salt': 0.009858381222611134,
#  'pickles': 0.004558797568629492,
#  'polenta': 0.010630075634610147,
#  'anise': 0.01172807225107153,
#  'plums': 0.020247992336989363,
#  'apple cider vinegar': 0.018242737887128133,
#  'toasted sesame seeds': 0.00454416243291329,
#  'chili pepper flakes': 0.007203872204793176,
#  'crushed pineapples in juice': 0.049529274156104156,
#  'beef tenderloin': 0.006861449579406899,
#  'fresh blueberries': 0.03786385403522548,
#  'angel hair': 0.0,
#  'vegetable stock': 0.010854505414496726,
#  'frozen corn kernels': 0.00811299051243749,
#  'poblano chiles': 0.006833002537326707,
#  'refried beans': 0.03125938511778317,
#  'non stick spray': 0.020361112371201487,
#  'Italian seasoned breadcrumbs': 0.025043851188600978,
#  'boneless skinless chicken': 0.022231796648174172,
#  'chicken stock cubes': 0.044920899742562394,
#  'fresh lime juice': 0.010742101971315601,
#  'sultana': 0.04288295264495407,
#  'corn syrup': 0.026813525279347755,
#  'gelatin': 0.042605230584839976,
#  'taco seasoning mix': 0.02987681875572574,
#  'processed cheese': 0.03758728928969239,
#  'onion tops': 0.010560212362360273,
#  'broth': 0.0,
#  'dumplings': 0.006843084938038099,
#  'red food coloring': 0.033487632989989115,
#  'color food green': 0.01470061690326731,
#  'pears': 0.012105333703846305,
#  'pound cake': 0.02585923120550468,
#  'chicken meat': 0.026970420009689765,
#  'nigella seeds': 0.033974612276916935,
#  'chopped garlic': 0.006591676214797029,
#  ...}

# %% [markdown]
# ## Computing the macro similarity graph

# %%
# Starting threshold
STARTING_THRESHOLD = 0.25

# Iwanthue palette for ten first communities
PALETTE = [
    '#c9587a',
    '#5dba5a',
    '#b65cbf',
    '#a3af44',
    '#747bc8',
    '#d49d43',
    '#4fbab7',
    '#d35238',
    '#588042',
    '#ac6f40'
]

# %%
similarity_graph = nx.Graph()

for ingredient, neighbors in MATRIX.items():
    for neighbor, cosine in neighbors.items():
        if cosine >= STARTING_THRESHOLD:
            similarity_graph.add_edge(ingredient, neighbor, cosine=cosine)

len(similarity_graph)
# Out:
# 1255

# %%
# Keeping only largest component
largest_component = set(max(nx.connected_components(similarity_graph), key=len))

for node in list(similarity_graph.nodes):
    if node not in largest_component:
        similarity_graph.remove_node(node)

# %%
# Community detection using the Louvain method
partition = community.best_partition(similarity_graph)

# Counting
communities_count = Counter()

for node, c in partition.items():
    communities_count[c] += 1
    
communities_colors = {}

i = 0
for c, _ in communities_count.most_common(10):
    communities_colors[c] = PALETTE[i]
    i += 1

# %%
# Styling
for node, attrs in similarity_graph.nodes(data=True):
    attrs['size'] = min(12, max(2, OCCURRENCES[node] / len(OCCURRENCES) * 6))
    attrs['color'] = communities_colors.get(partition[node], '#BBB')

# Display
Sigma(similarity_graph, height=1000)
# Out:
# Sigma(data={'nodes': [('romaine lettuce', {'size': 2, 'color': '#ac6f40'}), ('black pepper', {'size': 2.347631…

# %% [markdown]
# ## Computing the micro similarity graphs

# %%
communities = [set() for i in range(len(communities_count))]

for node, community in partition.items():
    communities[community].add(node)
    
communities = sorted(communities, key=lambda x: -len(x))

# %%
SUBVECTORS = {}

for community in communities:
    for item in community:
        SUBVECTORS[item] = Counter(dict((key, count) for key, count in VECTORS[item].items() if key in community))
        
SUBVECTORS['milk']
# Out:
# Counter({'eggs': 734, 'butter': 835, 'flour': 308})

# %%
SUBNORMS = {}
SUBSUMS = {}
for ingredient, vector in SUBVECTORS.items():
    SUBNORMS[ingredient] = math.sqrt(sum(map(lambda x: x * x, vector.values())))
    SUBSUMS[ingredient] = sum(vector.values())
    
SUBNORMS['milk']
# Out:
# 1153.6225552580013

# %%
# PMI computations
PMIS = []

for community in communities:
    pmi = defaultdict(dict)
    ntot = sum(sum(x for x in v.values()) for v in SUBVECTORS.values()) / 2
    PMIS.append(pmi)
    
    community = list(community)

    for i, kA in enumerate(community):
        for j in range(i + 1, len(community)):
            kB = community[j]
            nab = SUBVECTORS[kA].get(kB)
            
            if not nab:
                continue
            
            s = math.log(nab * ntot / (SUBSUMS[kA] * SUBSUMS[kB]))

            if s > 1:
                pmi[kA][kB] = s
                pmi[kB][kA] = s

# %%
MATRICES = []

for i, community in enumerate(communities):
    pmi = PMIS[i]
    m = defaultdict(dict)
    MATRICES.append(m)
    
    community = list(community)

    for i, kA in enumerate(community):
        sA = sum(pmi[kA].values())
        
        for j in range(i + 1, len(community)):
            kB = community[j]
            
            ks = set(pmi[kA].keys()) & set(pmi[kB].keys())

            d = sum(min(pmi[kA][k], pmi[kB][k]) for k in ks)

            if sA <= 0:
                continue

            s = d / sA

            m[kA][kB] = s
            m[kB][kA] = s

# %%
for i, c in enumerate(communities):
    if 'dried tart cherries' in c:
        for j, k in sorted(PMIS[i]['dried tart cherries'].items()):
            print(j, k, PMIS[i]['candied fruit'].get(j))
# Out:
# almond extract 2.131135156328938 None
# almonds 1.6403283994534388 None
# bartlett pears 3.662611527293326 None
# candied orange peel 2.6817822742815998 None
# caramel sauce 3.496626389819065 None
# cherries 2.7574940960172962 2.7679653958845916
# chocolate 2.7687936512712295 None
# chopped walnuts 1.7530690224088876 None
# cream of tartar 1.1469332188385721 None
# crème fraîche 2.1585341305170522 None
# dried apricot 1.9378627683482312 None
# egg whites 1.406943354087032 1.4174146539543275
# extract 3.7803945629497098 None
# golden brown sugar 1.9428255576903604 None
# golden raisins 2.0407510948606684 2.4566875028361284
# grated lemon peel 1.7286775692847285 None
# grated lemon zest 1.2459539780394326 1.256425277906728
# grated orange 1.7186874762096422 1.7291587760769376
# grated orange peel 2.536600264437102 1.8539243837444521
# ground allspice 1.0285268583474458 None
# ground almonds 2.6359727382503055 2.646444038117601
# hazelnuts 2.5187426470370955 1.8360667663444457
# honey 1.34213194442273 1.3526032442900253
# ice water 1.4054888083760377 None
# kirsch 4.1215653203524765 None
# maple syrup 1.9378627683482312 None
# margarine 1.6077757964156902 None
# orange rind 3.7961429199178487 3.113467039225199
# pecan halves 1.6607562221435368 None
# pound cake 3.496626389819065 None
# raspberry jam 3.1517859035273355 None
# semisweet chocolate 1.0807126115180161 1.0911839113853115
# slivered almonds 2.329805851124422 None
# sponge cake 3.950293599745107 3.9607648996124025
# turbinado 2.582691371637369 None
# unsweetened cocoa powder 1.2324153097066344 None
# vanilla beans 1.2434787292508898 1.9470972096781305
# vegetable shortening 1.5762495427689163 None
# whipping cream 1.0400586983495306 1.0505299982168261
# yellow corn meal 1.0671495449703954 None

# %%
similarity_graphs = []

SUB_THRESHOLD = 0.65

for i in range(len(communities)):
    m = MATRICES[i]
    g = nx.Graph()
    similarity_graphs.append(g)
    
    for ingredient, neighbors in m.items():
        for neighbor, cosine in neighbors.items():
            if cosine >= SUB_THRESHOLD:
                g.add_edge(ingredient, neighbor, cosine=cosine)

# %%
graph = similarity_graphs[1]

# Styling
for node, attrs in graph.nodes(data=True):
    attrs['size'] = min(12, max(2, OCCURRENCES[node] / len(OCCURRENCES) * 6))
    # attrs['color'] = communities_colors.get(partition[node], '#BBB')

# Display
Sigma(graph)
# Out:
# Sigma(data={'nodes': [('sage leaves', {'size': 2}), ('pancetta', {'size': 2}), ('chopped fresh sage', {'size':…
